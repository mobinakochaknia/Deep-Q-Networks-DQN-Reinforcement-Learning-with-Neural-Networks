# %% [markdown]
# <img src='http://www-scf.usc.edu/~ghasemig/images/sharif.png' alt="SUT logo" width=300 height=300 align=left class="saturate" >
#
# <br>
# <font>
# <div dir=ltr align=center>
# <font color=0F5298 size=7>
#     Artificial Intelligence <br>
# <font color=2565AE size=5>
#     Computer Engineering Department <br>
#     Fall 2024<br>
# <div dir=ltr align=center>
#
# <font color=3C99D size=5>
#     Practical Assignment 5 - Reinforcement Learning <br>
# <font color=696880 size=4>
#     Kiarash Joolaei

# %% [markdown]
# # Personal Data

# %%
name = 'mobina kochaknia'

# %% [markdown]
# **Note :** This notebook is optional.

# %% [markdown]
# Although in many cases classic RL algorithms such as  QLearning perform pretty well, there are also cases where they can fall short. In this notebook we will explore these shortcomings while also introducing more effective variants for such algorithms.

# %% [markdown]
# # Q-Learning vs. Deep Q-Learning

# %% [markdown]
# ### Q-Learning
#
# **Q-Learning** is a model-free reinforcement learning algorithm used to learn the optimal action-value function $ Q(s, a) $ for a given environment. It operates by iteratively updating $ Q $-values using the Bellman equation, based on the rewards received and the agent's estimate of future rewards. Q-learning is effective in small, discrete state-action spaces where a table can be used to store $ Q $-values. However, as the size or complexity of the environment grows, maintaining and updating a table for all state-action pairs becomes computationally infeasible, and the algorithm struggles to generalize across states.
#
# ### Deep Q-Learning
#
# **Deep Q-Learning (DQN)** addresses these limitations by approximating the $ Q $-value function using a deep neural network. Instead of storing $ Q(s, a) $ values in a table, the neural network takes a state $ s $ as input and outputs $ Q $-values for all possible actions. This allows DQN to handle environments with large or continuous state spaces, such as video games or robotics tasks. Deep Q-learning also introduces techniques like experience replay and target networks to stabilize training. DQN is particularly needed in scenarios where the state space is high-dimensional, such as pixel-based input (e.g., images from a game), where tabular methods are impractical, and learning representations through a neural network is necessary for effective decision-making.

# %% [markdown]
# Here we will implement both Q-Learning and Deep Q-Learning on the environment `LunarLander-v2`. This environment consists of a Discrete action space with four possible actions:
#
# 0: do nothing
#
# 1: fire left orientation engine
#
# 2: fire main engine
#
# 3: fire right orientation engine
#
# The state space however consists of 8-dimensional continuous states: the coordinates of the lander in x & y, its linear velocities in x & y, its angle, its angular velocity, and two booleans that represent whether each leg is in contact with the ground or not. The continuity of the state space lets us use a neural network to estimate $Q$-values as a function with state as input and $Q$-values for all actions.

# %% [markdown]
# # Libraries

# %%
# !sudo apt-get update --quiet
# !pip install imageio --quiet
# !sudo apt-get install -y xvfb ffmpeg --quiet
# !pip install swig --quiet
# !pip install gymnasium[box2d] --quiet
from IPython.display import clear_output
clear_output()

# %% [markdown]
# Import the neccesary libraries here.

# %%
import gymnasium as gym
import random
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
from collections import namedtuple, deque

import base64
import json
import imageio
import IPython

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import random
import time
from IPython.display import clear_output, HTML
from base64 import b64encode
from moviepy.editor import ImageSequenceClip
from typing import Tuple


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
! pip install gymnasium
! pip install gymnasium[box2d]
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (4.3.0)

# %% [markdown]
# These are some helper functions that can visualize the outcome of a sampled trajectory. They will be useful later.

# %%
import logging
logging.getLogger().setLevel(logging.ERROR)

is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display
plt.ion()
plt.xkcd(scale=1, length=100, randomness=2)
matplotlib.rcParams['figure.figsize'] = (12, 6)


def plot_rewards(sum_of_rewards, show_result=False):
    plt.figure(1)
    rewards = torch.tensor(sum_of_rewards, dtype=torch.float)
    if show_result:
        plt.title('Result')
    else:
        plt.clf()
        plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.plot(rewards.numpy())
    # Take 50 episode averages and plot them too
    length = len(rewards)
    init_len = min(49, length)
    init_means = np.cumsum(rewards[:init_len]) / (1 + np.arange(init_len))
    if length > 50:
        means = rewards.unfold(0, 50, 1).mean(1).view(-1)
        means = torch.cat((init_means, means))
    else:
        means = init_means
    plt.plot(means.numpy())

    plt.pause(0.001)  # pause a bit so that plots are updated
    if is_ipython:
        if not show_result:
            display.display(plt.gcf())
            display.clear_output(wait=True)
        else:
            display.display(plt.gcf())


def embed_mp4(filename):
    video = open(filename,'rb').read()
    b64 = base64.b64encode(video)
    tag = '''
    <video width="640" height="480" controls>
    <source src="data:video/mp4;base64,{0}" type="video/mp4">
    Your browser does not support the video tag.
    </video>'''.format(b64.decode())
    return IPython.display.HTML(tag)


def create_policy_eval_video(env, agent, filename, num_episodes=1, fps=30):
    """
    Creates a video of the agent interacting with the environment using its policy.
    Args:
        env: The environment to evaluate.
        agent: The agent to evaluate.
        filename: The name of the video file to save.
        num_episodes: Number of episodes to record.
        fps: Frames per second for the video.
    Returns:
        HTML object for embedding the video in Jupyter Notebook.
    """
    filename = filename + ".mp4"
    with imageio.get_writer(filename, fps=fps) as video:
        for _ in range(num_episodes):
            state, _ = env.reset()
            video.append_data(env.render())
            done = False
            while not done:
                state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(agent.device)
                action = agent.act(state_tensor, greedy=True)  # Select greedy action
                next_state, reward, terminated, truncated, _ = env.step(action)  # Removed .item()
                done = terminated or truncated
                video.append_data(env.render())
                state = next_state

    # Return video for display
    with open(filename, 'rb') as f:
        video_data = f.read()
    b64_video = base64.b64encode(video_data).decode()
    return HTML(f"""
        <video width="640" height="480" controls>
            <source src="data:video/mp4;base64,{b64_video}" type="video/mp4">
        </video>
    """)

def save_progress(sum_of_rewards, PATH):
    # Convert the list to a JSON string
    json_data = json.dumps(sum_of_rewards)
    # Write the JSON data to a file
    with open(PATH + str('.json'), "w") as file:
        file.write(json_data)


def load_progress(PATH):
    with open(PATH + str('.json'), "r") as file:
        json_data = file.read()
    # Load the JSON data back into a Python list
    return json.loads(json_data)

# %% [markdown]
# # Q-Learning

# %% [markdown]
# Here you should implement the `QLearningAgent` class. Note that since the state space is continuous, you will need to discretize states as some state bins in order to use the classic Q-Learning algorithm (number of bins is optional).

# %%
import numpy as np

class QLearningAgent(object):
    def __init__(self, env, learning_rate, discount_factor, epsilon, epsilon_decay, epsilon_min, state_bins):
        self.env = env
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.state_bins = state_bins  # List of bins for discretizing each dimension of state

        # Initialize Q-table with zeros
        self.q_table = np.zeros([*(len(bins) + 1 for bins in state_bins), env.action_space.n])

    def discretize_state(self, state):
        """
        Discretizes a continuous state into discrete bins.
        """
        discrete_state = []
        for dim, bins in zip(state, self.state_bins):
            discrete_state.append(np.digitize(dim, bins))
        return tuple(discrete_state)

    def act(self, state, greedy=True):
        """
        Selects an action based on epsilon-greedy policy.
        """
        discrete_state = self.discretize_state(state)
        if greedy or np.random.rand() > self.epsilon:
            return np.argmax(self.q_table[discrete_state])
        else:
            return self.env.action_space.sample()

    def update_q_value(self, state, action, reward, next_state, done):
        """
        Updates the Q-value for the given state-action pair.
        """
        discrete_state = self.discretize_state(state)
        discrete_next_state = self.discretize_state(next_state)

        # Compute the target Q-value
        target = reward
        if not done:
            target += self.discount_factor * np.max(self.q_table[discrete_next_state])

        # Update the Q-value using the learning rate
        self.q_table[discrete_state][action] += self.learning_rate * (target - self.q_table[discrete_state][action])

    def decay_epsilon(self):
        """
        Decays epsilon for exploration.
        """
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

    def train(self, num_episodes):
        """
        Train the agent for a specified number of episodes.
        """
        rewards = []
        for episode in range(num_episodes):
            state, _ = self.env.reset()
            total_reward = 0
            done = False

            while not done:
                action = self.act(state, greedy=False)
                next_state, reward, terminated, truncated, _ = self.env.step(action)
                done = terminated or truncated

                self.update_q_value(state, action, reward, next_state, done)
                total_reward += reward
                state = next_state

            self.decay_epsilon()
            rewards.append(total_reward)

            print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward:.2f}, Epsilon: {self.epsilon:.3f}")

        return rewards

# %% [markdown]
# # Deep Q-Network

# %% [markdown]
# In this part, you need to implement a deep q-network (DQN). When implementing DQN it's common to use a replay buffer. A replay buffer in deep reinforcement learning stores past experiences so the agent can sample them randomly during training. This helps break correlations in sequential data, improves sample efficiency by reusing experiences, stabilizes training by providing a consistent data distribution, and reduces the variance in gradient updates. The class `ReplayBuffer` code is given to you. Push the trajectory to the buffer while training the network and sample from it when updating the network.

# %% [markdown]
# <p align="center">
#   <img src="https://www.researchgate.net/publication/346346921/figure/fig5/AS:962138164178960@1606403022784/llustration-of-the-replay-buffer-in-the-RL.ppm" alt="Replay Buffer Illustration" width="600">
# </p>

# %%
# Define Replay Buffer
class ReplayBuffer:
    def __init__(self, capacity, batch_size):
        self.memory = deque([], maxlen=capacity)
        self.batch_size = batch_size
        self.experience = namedtuple('Experience', ('state', 'action', 'reward', 'next_state', 'done'))

    def push(self, state, action, reward, next_state, done):
        # Convert all inputs to tensors
        new_experience = self.experience(
            state=torch.tensor(state, dtype=torch.float32).unsqueeze(0),
            action=torch.tensor([action], dtype=torch.int64),
            reward=torch.tensor([reward], dtype=torch.float32),
            next_state=torch.tensor(next_state, dtype=torch.float32).unsqueeze(0),
            done=torch.tensor([done], dtype=torch.bool)
        )
        self.memory.append(new_experience)

    def sample(self):
        experiences = random.sample(self.memory, self.batch_size)
        states = torch.cat([e.state for e in experiences])
        actions = torch.cat([e.action for e in experiences])
        rewards = torch.cat([e.reward for e in experiences])
        next_states = torch.cat([e.next_state for e in experiences])
        dones = torch.cat([e.done for e in experiences])
        return states, actions, rewards, next_states, dones

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# In this part we must design our Agent class which is the must important part of the notebook. First let's take a look at its methods:
#
#
# *   `__init__` : initializes the agent, by receiving it the q_network, replay memory, optimize, criterion, and a dictionary of paramters which hold the hyperparameters of the agent.
# *   `step` : allows the agent to store an experience in its memory and if necessary, it initiates the learning process.
# *   `act` : by receiving a state and boolean value for choosing a greedy action, if the boolean value is false, it selects an $\varepsilon$-greedy action by passing the state to the policy network of the agent, and select the action with the highest state-action value. The $\varepsilon$ value is calculated using the following formula: $$\varepsilon = \varepsilon_{end} + \left(\varepsilon_{start} - \varepsilon_{end}\right)\exp\left(-\frac{\text{steps done}}{\text{decay rate}}\right)$$
# *   `learn` : first computes the predicted Q-values for the observed states and actions using the policy network. Then, it computes the expected Q-values for the next states by evaluating the target network, incorporating rewards and discount factors. After computing the loss between predicted and expected Q-values, the function optimizes the model parameters using gradient descent. Additionally, it calls the soft update function to gradually update the target network's parameters towards the policy network's parameters.
# *   `soft_update` : The target network is updated at every step with a soft update controlled by the hyperparameter $\tau$, which was previously defined. The target is updated according to: $$\theta' \leftarrow \tau \theta + (1 - \tau) \theta'$$ where $\theta'$ are the parameters of the target network and $\theta$ are the parameters of the policy network.
# *   `save` and `load` : are used for saving and loading the policy and target networks of the agent.

# %%
class QNetwork(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_dims):
        super(QNetwork, self).__init__()
        layers = []

        # Input layer
        layers.append(nn.Linear(input_dim, hidden_dims[0]))
        layers.append(nn.ReLU())

        # Hidden layers
        for i in range(len(hidden_dims) - 1):
            layers.append(nn.Linear(hidden_dims[i], hidden_dims[i + 1]))
            layers.append(nn.ReLU())

        # Output layer
        layers.append(nn.Linear(hidden_dims[-1], output_dim))
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# %%
class DQLearningAgent:
    def __init__(self, q_network, memory, optimizer, criterion, params, env):
        self.policy_net = q_network.to(params['DEVICE'])
        self.target_net = q_network.to(params['DEVICE'])
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        self.memory = memory
        self.criterion = criterion
        self.optimizer = optimizer(self.policy_net.parameters(), lr=params['LR'])

        # Hyperparameters
        self.gamma = params['GAMMA']
        self.tau = params['TAU']
        self.epsilon = params['EPS_START']
        self.eps_end = params['EPS_END']
        self.eps_decay = params['EPS_DECAY']
        self.update_rate = params['UPDATE_RATE']
        self.env = env
        self.device = params['DEVICE']
        self.steps_done = 0

    def act(self, state, greedy=False):
        """
        Select an action based on epsilon-greedy policy.
        Args:
            state: Current state.
            greedy: If True, always select the greedy action.
        Returns:
            Selected action.
        """
        eps_threshold = self.eps_end + (self.epsilon - self.eps_end) * np.exp(-self.steps_done / self.eps_decay)
        if greedy or np.random.rand() > eps_threshold:
            with torch.no_grad():
                state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(self.device)
                q_values = self.policy_net(state)
                return q_values.argmax(dim=-1).item()  # Select the action with the highest Q-value
        else:
            return self.env.action_space.sample()

    def step(self, state, action, reward, next_state, done):
        self.memory.push(state, action, reward, next_state, done)
        self.steps_done += 1

        if len(self.memory) > self.memory.batch_size and self.steps_done % self.update_rate == 0:
            self.learn(*self.memory.sample())

    def learn(self, states, actions, rewards, next_states, dones):
        states = states.to(self.device)
        actions = actions.to(self.device)
        rewards = rewards.to(self.device)
        next_states = next_states.to(self.device)
        dones = dones.to(self.device)

        q_values = self.policy_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)
        with torch.no_grad():
            max_next_q_values = self.target_net(next_states).max(dim=1)[0]
            target_q_values = rewards + (1 - dones.float()) * self.gamma * max_next_q_values

        loss = self.criterion(q_values, target_q_values)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        self.soft_update()

    def soft_update(self):
        for target_param, policy_param in zip(self.target_net.parameters(), self.policy_net.parameters()):
            target_param.data.copy_(self.tau * policy_param.data + (1.0 - self.tau) * target_param.data)

    def train(self, num_episodes):
        rewards = []

        for episode in range(num_episodes):
            state, _ = self.env.reset()
            total_reward = 0
            done = False

            while not done:
                action = self.act(state, greedy=False)
                next_state, reward, terminated, truncated, _ = self.env.step(action)
                done = terminated or truncated

                self.step(state, action, reward, next_state, done)
                total_reward += reward
                state = next_state

            self.epsilon = max(self.eps_end, self.epsilon * self.eps_decay)
            rewards.append(total_reward)

            if (episode + 1) % 10 == 0:
                avg_reward = np.mean(rewards[-10:])
                print(f"Episode {episode + 1}/{num_episodes}, Average Reward: {avg_reward:.2f}, Epsilon: {self.epsilon:.3f}")

        return rewards

# %% [markdown]
# # Training

# %% [markdown]
# Everything is now set to test on `LunarLander-v3`. Set the sutiable hyperparameters for both Q-Learning and DQN and plot the rewards for each as well.

# %%
env = gym.make("LunarLander-v3")
spec = gym.spec("LunarLander-v3")

print(f"Action Space: {env.action_space}")
print(f"Observation Space: {env.observation_space}")
print(f"Max Episode Steps: {spec.max_episode_steps}")
print(f"Nondeterministic: {spec.nondeterministic}")
print(f"Reward Threshold: {spec.reward_threshold}\n")
# Out:
# Action Space: Discrete(4)
# Observation Space: Box([ -2.5        -2.5       -10.        -10.         -6.2831855 -10.
#   -0.         -0.       ], [ 2.5        2.5       10.        10.         6.2831855 10.
#   1.         1.       ], (8,), float32)
# Max Episode Steps: 1000
# Nondeterministic: False
# Reward Threshold: 200

# %%
# Define hyperparameters and constants
state_bins = [np.linspace(-1, 1, 10) for _ in range(8)]  # Discretize each dimension of state space
learning_rate = 0.001  # Learning rate for the optimizer
discount_factor = 0.99  # Gamma, the discount factor for future rewards
epsilon = 1.0  # Starting epsilon value for epsilon-greedy policy
epsilon_decay = 0.995  # Decay rate for epsilon
epsilon_min = 0.01  # Minimum value of epsilon
batch_size = 64  # Size of batches sampled from the replay buffer
memory_capacity = 100000  # Maximum size of the replay memory
target_update_frequency = 10  # Frequency (in episodes) to update the target network
hidden_dim = [128, 64]  # Hidden layer dimensions for the Q-network
num_episodes = 1000  # Total number of training episodes

# %%
# Q-Learning
q_agent = QLearningAgent(
    env=env,
    state_bins=state_bins,
    learning_rate=learning_rate,
    discount_factor=discount_factor,
    epsilon=epsilon,
    epsilon_decay=epsilon_decay,
    epsilon_min=epsilon_min,
)
rewards = q_agent.train(num_episodes=num_episodes)
plot_rewards(rewards, show_result=True)
plt.ioff()
plt.show()
# Out:
# Episode 1/1000, Total Reward: -190.31, Epsilon: 0.995
# Episode 2/1000, Total Reward: -77.84, Epsilon: 0.990
# Episode 3/1000, Total Reward: -180.20, Epsilon: 0.985
# Episode 4/1000, Total Reward: -138.50, Epsilon: 0.980
# Episode 5/1000, Total Reward: -103.84, Epsilon: 0.975
# Episode 6/1000, Total Reward: -3.74, Epsilon: 0.970
# Episode 7/1000, Total Reward: -38.26, Epsilon: 0.966
# Episode 8/1000, Total Reward: -168.03, Epsilon: 0.961
# Episode 9/1000, Total Reward: -81.24, Epsilon: 0.956
# Episode 10/1000, Total Reward: -456.85, Epsilon: 0.951
# Episode 11/1000, Total Reward: -76.80, Epsilon: 0.946
# Episode 12/1000, Total Reward: -123.89, Epsilon: 0.942
# Episode 13/1000, Total Reward: -341.39, Epsilon: 0.937
# Episode 14/1000, Total Reward: -323.52, Epsilon: 0.932
# Episode 15/1000, Total Reward: -139.27, Epsilon: 0.928
# Episode 16/1000, Total Reward: -74.05, Epsilon: 0.923
# Episode 17/1000, Total Reward: -221.86, Epsilon: 0.918
# Episode 18/1000, Total Reward: -336.34, Epsilon: 0.914
# Episode 19/1000, Total Reward: -109.58, Epsilon: 0.909
# Episode 20/1000, Total Reward: -179.47, Epsilon: 0.905
# Episode 21/1000, Total Reward: -131.98, Epsilon: 0.900
# Episode 22/1000, Total Reward: -213.95, Epsilon: 0.896
# Episode 23/1000, Total Reward: -116.58, Epsilon: 0.891
# Episode 24/1000, Total Reward: -216.07, Epsilon: 0.887
# Episode 25/1000, Total Reward: -209.40, Epsilon: 0.882
# Episode 26/1000, Total Reward: -80.91, Epsilon: 0.878
# Episode 27/1000, Total Reward: -230.52, Epsilon: 0.873
# Episode 28/1000, Total Reward: -135.81, Epsilon: 0.869
# Episode 29/1000, Total Reward: -131.88, Epsilon: 0.865
# Episode 30/1000, Total Reward: -26.35, Epsilon: 0.860
# Episode 31/1000, Total Reward: -280.50, Epsilon: 0.856
# Episode 32/1000, Total Reward: -427.73, Epsilon: 0.852
# Episode 33/1000, Total Reward: -125.09, Epsilon: 0.848
# Episode 34/1000, Total Reward: -139.93, Epsilon: 0.843
# Episode 35/1000, Total Reward: -259.51, Epsilon: 0.839
# Episode 36/1000, Total Reward: -122.71, Epsilon: 0.835
# Episode 37/1000, Total Reward: -94.14, Epsilon: 0.831
# Episode 38/1000, Total Reward: -75.35, Epsilon: 0.827
# Episode 39/1000, Total Reward: -108.78, Epsilon: 0.822
# Episode 40/1000, Total Reward: -394.22, Epsilon: 0.818
# Episode 41/1000, Total Reward: -314.47, Epsilon: 0.814
# Episode 42/1000, Total Reward: -110.12, Epsilon: 0.810
# Episode 43/1000, Total Reward: -337.64, Epsilon: 0.806
# Episode 44/1000, Total Reward: -53.33, Epsilon: 0.802
# Episode 45/1000, Total Reward: -118.33, Epsilon: 0.798
# Episode 46/1000, Total Reward: -121.80, Epsilon: 0.794
# Episode 47/1000, Total Reward: -200.86, Epsilon: 0.790
# Episode 48/1000, Total Reward: -335.22, Epsilon: 0.786
# Episode 49/1000, Total Reward: -387.53, Epsilon: 0.782
# Episode 50/1000, Total Reward: -74.76, Epsilon: 0.778
# Episode 51/1000, Total Reward: -1.38, Epsilon: 0.774
# Episode 52/1000, Total Reward: -118.95, Epsilon: 0.771
# Episode 53/1000, Total Reward: -128.94, Epsilon: 0.767
# Episode 54/1000, Total Reward: -98.33, Epsilon: 0.763
# Episode 55/1000, Total Reward: -92.54, Epsilon: 0.759
# Episode 56/1000, Total Reward: -53.43, Epsilon: 0.755
# Episode 57/1000, Total Reward: -93.22, Epsilon: 0.751
# Episode 58/1000, Total Reward: -90.18, Epsilon: 0.748
# Episode 59/1000, Total Reward: -151.69, Epsilon: 0.744
# Episode 60/1000, Total Reward: -242.38, Epsilon: 0.740
# Episode 61/1000, Total Reward: -418.43, Epsilon: 0.737
# Episode 62/1000, Total Reward: -63.72, Epsilon: 0.733
# Episode 63/1000, Total Reward: -264.81, Epsilon: 0.729
# Episode 64/1000, Total Reward: -165.09, Epsilon: 0.726
# Episode 65/1000, Total Reward: -86.24, Epsilon: 0.722
# Episode 66/1000, Total Reward: -54.99, Epsilon: 0.718
# Episode 67/1000, Total Reward: -212.82, Epsilon: 0.715
# Episode 68/1000, Total Reward: -94.88, Epsilon: 0.711
# Episode 69/1000, Total Reward: -65.34, Epsilon: 0.708
# Episode 70/1000, Total Reward: -256.85, Epsilon: 0.704
# Episode 71/1000, Total Reward: -134.63, Epsilon: 0.701
# Episode 72/1000, Total Reward: -351.28, Epsilon: 0.697
# Episode 73/1000, Total Reward: -55.96, Epsilon: 0.694
# Episode 74/1000, Total Reward: 22.65, Epsilon: 0.690
# Episode 75/1000, Total Reward: -514.27, Epsilon: 0.687
# Episode 76/1000, Total Reward: -76.83, Epsilon: 0.683
# Episode 77/1000, Total Reward: -124.80, Epsilon: 0.680
# Episode 78/1000, Total Reward: -250.71, Epsilon: 0.676
# Episode 79/1000, Total Reward: -375.08, Epsilon: 0.673
# Episode 80/1000, Total Reward: -186.22, Epsilon: 0.670
# Episode 81/1000, Total Reward: -74.50, Epsilon: 0.666
# Episode 82/1000, Total Reward: -211.41, Epsilon: 0.663
# Episode 83/1000, Total Reward: -87.85, Epsilon: 0.660
# Episode 84/1000, Total Reward: -233.17, Epsilon: 0.656
# Episode 85/1000, Total Reward: -103.51, Epsilon: 0.653
# Episode 86/1000, Total Reward: -80.38, Epsilon: 0.650
# Episode 87/1000, Total Reward: -321.19, Epsilon: 0.647
# Episode 88/1000, Total Reward: -203.69, Epsilon: 0.643
# Episode 89/1000, Total Reward: -181.70, Epsilon: 0.640
# Episode 90/1000, Total Reward: -106.83, Epsilon: 0.637
# Episode 91/1000, Total Reward: -186.13, Epsilon: 0.634
# Episode 92/1000, Total Reward: -225.99, Epsilon: 0.631
# Episode 93/1000, Total Reward: -106.75, Epsilon: 0.627
# Episode 94/1000, Total Reward: -12.72, Epsilon: 0.624
# Episode 95/1000, Total Reward: -83.04, Epsilon: 0.621
# Episode 96/1000, Total Reward: -138.78, Epsilon: 0.618
# Episode 97/1000, Total Reward: -148.72, Epsilon: 0.615
# Episode 98/1000, Total Reward: -89.29, Epsilon: 0.612
# Episode 99/1000, Total Reward: -132.61, Epsilon: 0.609
# Episode 100/1000, Total Reward: -142.76, Epsilon: 0.606
# Episode 101/1000, Total Reward: -161.40, Epsilon: 0.603
# Episode 102/1000, Total Reward: -96.90, Epsilon: 0.600
# Episode 103/1000, Total Reward: -362.56, Epsilon: 0.597
# Episode 104/1000, Total Reward: -49.15, Epsilon: 0.594
# Episode 105/1000, Total Reward: -105.06, Epsilon: 0.591
# Episode 106/1000, Total Reward: -238.82, Epsilon: 0.588
# Episode 107/1000, Total Reward: -209.31, Epsilon: 0.585
# Episode 108/1000, Total Reward: -104.94, Epsilon: 0.582
# Episode 109/1000, Total Reward: -239.69, Epsilon: 0.579
# Episode 110/1000, Total Reward: -96.61, Epsilon: 0.576
# Episode 111/1000, Total Reward: -70.47, Epsilon: 0.573
# Episode 112/1000, Total Reward: -359.80, Epsilon: 0.570
# Episode 113/1000, Total Reward: -138.28, Epsilon: 0.568
# Episode 114/1000, Total Reward: -274.18, Epsilon: 0.565
# Episode 115/1000, Total Reward: -49.19, Epsilon: 0.562
# Episode 116/1000, Total Reward: -278.66, Epsilon: 0.559
# Episode 117/1000, Total Reward: -207.20, Epsilon: 0.556
# Episode 118/1000, Total Reward: -348.40, Epsilon: 0.554
# Episode 119/1000, Total Reward: -242.29, Epsilon: 0.551
# Episode 120/1000, Total Reward: -72.92, Epsilon: 0.548
# Episode 121/1000, Total Reward: -188.27, Epsilon: 0.545
# Episode 122/1000, Total Reward: -108.18, Epsilon: 0.543
# Episode 123/1000, Total Reward: -202.60, Epsilon: 0.540
# Episode 124/1000, Total Reward: -88.36, Epsilon: 0.537
# Episode 125/1000, Total Reward: -98.91, Epsilon: 0.534
# Episode 126/1000, Total Reward: -153.44, Epsilon: 0.532
# Episode 127/1000, Total Reward: -240.70, Epsilon: 0.529
# Episode 128/1000, Total Reward: -102.81, Epsilon: 0.526
# Episode 129/1000, Total Reward: -75.53, Epsilon: 0.524
# Episode 130/1000, Total Reward: -172.32, Epsilon: 0.521
# Episode 131/1000, Total Reward: -80.91, Epsilon: 0.519
# Episode 132/1000, Total Reward: 47.82, Epsilon: 0.516
# Episode 133/1000, Total Reward: -49.11, Epsilon: 0.513
# Episode 134/1000, Total Reward: -200.74, Epsilon: 0.511
# Episode 135/1000, Total Reward: -144.48, Epsilon: 0.508
# Episode 136/1000, Total Reward: -115.07, Epsilon: 0.506
# Episode 137/1000, Total Reward: -140.42, Epsilon: 0.503
# Episode 138/1000, Total Reward: -149.14, Epsilon: 0.501
# Episode 139/1000, Total Reward: -141.39, Epsilon: 0.498
# Episode 140/1000, Total Reward: -85.60, Epsilon: 0.496
# Episode 141/1000, Total Reward: -93.98, Epsilon: 0.493
# Episode 142/1000, Total Reward: -330.03, Epsilon: 0.491
# Episode 143/1000, Total Reward: 14.94, Epsilon: 0.488
# Episode 144/1000, Total Reward: -271.63, Epsilon: 0.486
# Episode 145/1000, Total Reward: -137.36, Epsilon: 0.483
# Episode 146/1000, Total Reward: -186.29, Epsilon: 0.481
# Episode 147/1000, Total Reward: -201.49, Epsilon: 0.479
# Episode 148/1000, Total Reward: -147.49, Epsilon: 0.476
# Episode 149/1000, Total Reward: -219.17, Epsilon: 0.474
# Episode 150/1000, Total Reward: -193.45, Epsilon: 0.471
# Episode 151/1000, Total Reward: -97.38, Epsilon: 0.469
# Episode 152/1000, Total Reward: -106.07, Epsilon: 0.467
# Episode 153/1000, Total Reward: -114.14, Epsilon: 0.464
# Episode 154/1000, Total Reward: -84.46, Epsilon: 0.462
# Episode 155/1000, Total Reward: -144.43, Epsilon: 0.460
# Episode 156/1000, Total Reward: -71.91, Epsilon: 0.458
# Episode 157/1000, Total Reward: -138.52, Epsilon: 0.455
# Episode 158/1000, Total Reward: -142.82, Epsilon: 0.453
# Episode 159/1000, Total Reward: -284.14, Epsilon: 0.451
# Episode 160/1000, Total Reward: -228.84, Epsilon: 0.448
# Episode 161/1000, Total Reward: -207.51, Epsilon: 0.446
# Episode 162/1000, Total Reward: -176.25, Epsilon: 0.444
# Episode 163/1000, Total Reward: -256.92, Epsilon: 0.442
# Episode 164/1000, Total Reward: -88.34, Epsilon: 0.440
# Episode 165/1000, Total Reward: -233.82, Epsilon: 0.437
# Episode 166/1000, Total Reward: -82.20, Epsilon: 0.435
# Episode 167/1000, Total Reward: -101.78, Epsilon: 0.433
# Episode 168/1000, Total Reward: -85.07, Epsilon: 0.431
# Episode 169/1000, Total Reward: -296.23, Epsilon: 0.429
# Episode 170/1000, Total Reward: -107.44, Epsilon: 0.427
# Episode 171/1000, Total Reward: -443.80, Epsilon: 0.424
# Episode 172/1000, Total Reward: -155.32, Epsilon: 0.422
# Episode 173/1000, Total Reward: -77.13, Epsilon: 0.420
# Episode 174/1000, Total Reward: -60.88, Epsilon: 0.418
# Episode 175/1000, Total Reward: -374.68, Epsilon: 0.416
# Episode 176/1000, Total Reward: -72.02, Epsilon: 0.414
# Episode 177/1000, Total Reward: -218.52, Epsilon: 0.412
# Episode 178/1000, Total Reward: -60.44, Epsilon: 0.410
# Episode 179/1000, Total Reward: -115.29, Epsilon: 0.408
# Episode 180/1000, Total Reward: -127.84, Epsilon: 0.406
# Episode 181/1000, Total Reward: -334.40, Epsilon: 0.404
# Episode 182/1000, Total Reward: -111.58, Epsilon: 0.402
# Episode 183/1000, Total Reward: -134.37, Epsilon: 0.400
# Episode 184/1000, Total Reward: -85.90, Epsilon: 0.398
# Episode 185/1000, Total Reward: -186.40, Epsilon: 0.396
# Episode 186/1000, Total Reward: -104.75, Epsilon: 0.394
# Episode 187/1000, Total Reward: -98.22, Epsilon: 0.392
# Episode 188/1000, Total Reward: -180.25, Epsilon: 0.390
# Episode 189/1000, Total Reward: -141.11, Epsilon: 0.388
# Episode 190/1000, Total Reward: -236.60, Epsilon: 0.386
# Episode 191/1000, Total Reward: -243.54, Epsilon: 0.384
# Episode 192/1000, Total Reward: -230.12, Epsilon: 0.382
# Episode 193/1000, Total Reward: -57.17, Epsilon: 0.380
# Episode 194/1000, Total Reward: -361.49, Epsilon: 0.378
# Episode 195/1000, Total Reward: -47.79, Epsilon: 0.376
# Episode 196/1000, Total Reward: -138.46, Epsilon: 0.374
# Episode 197/1000, Total Reward: -231.79, Epsilon: 0.373
# Episode 198/1000, Total Reward: 27.65, Epsilon: 0.371
# Episode 199/1000, Total Reward: -221.01, Epsilon: 0.369
# Episode 200/1000, Total Reward: -86.35, Epsilon: 0.367
# Episode 201/1000, Total Reward: -199.77, Epsilon: 0.365
# Episode 202/1000, Total Reward: -216.38, Epsilon: 0.363
# Episode 203/1000, Total Reward: -227.95, Epsilon: 0.361
# Episode 204/1000, Total Reward: -232.94, Epsilon: 0.360
# Episode 205/1000, Total Reward: -89.05, Epsilon: 0.358
# Episode 206/1000, Total Reward: -59.58, Epsilon: 0.356
# Episode 207/1000, Total Reward: -184.94, Epsilon: 0.354
# Episode 208/1000, Total Reward: -183.20, Epsilon: 0.353
# Episode 209/1000, Total Reward: -103.36, Epsilon: 0.351
# Episode 210/1000, Total Reward: -96.25, Epsilon: 0.349
# Episode 211/1000, Total Reward: -190.37, Epsilon: 0.347
# Episode 212/1000, Total Reward: -107.26, Epsilon: 0.346
# Episode 213/1000, Total Reward: -171.33, Epsilon: 0.344
# Episode 214/1000, Total Reward: -300.85, Epsilon: 0.342
# Episode 215/1000, Total Reward: -64.94, Epsilon: 0.340
# Episode 216/1000, Total Reward: -111.48, Epsilon: 0.339
# Episode 217/1000, Total Reward: -116.69, Epsilon: 0.337
# Episode 218/1000, Total Reward: -92.20, Epsilon: 0.335
# Episode 219/1000, Total Reward: -270.83, Epsilon: 0.334
# Episode 220/1000, Total Reward: -141.17, Epsilon: 0.332
# Episode 221/1000, Total Reward: -175.09, Epsilon: 0.330
# Episode 222/1000, Total Reward: -298.06, Epsilon: 0.329
# Episode 223/1000, Total Reward: -107.51, Epsilon: 0.327
# Episode 224/1000, Total Reward: -62.81, Epsilon: 0.325
# Episode 225/1000, Total Reward: -115.50, Epsilon: 0.324
# Episode 226/1000, Total Reward: -113.87, Epsilon: 0.322
# Episode 227/1000, Total Reward: -141.42, Epsilon: 0.321
# Episode 228/1000, Total Reward: -68.25, Epsilon: 0.319
# Episode 229/1000, Total Reward: -209.83, Epsilon: 0.317
# Episode 230/1000, Total Reward: -188.04, Epsilon: 0.316
# Episode 231/1000, Total Reward: -138.87, Epsilon: 0.314
# Episode 232/1000, Total Reward: -59.84, Epsilon: 0.313
# Episode 233/1000, Total Reward: -187.36, Epsilon: 0.311
# Episode 234/1000, Total Reward: -141.66, Epsilon: 0.309
# Episode 235/1000, Total Reward: -49.65, Epsilon: 0.308
# Episode 236/1000, Total Reward: -117.20, Epsilon: 0.306
# Episode 237/1000, Total Reward: -153.22, Epsilon: 0.305
# Episode 238/1000, Total Reward: -116.75, Epsilon: 0.303
# Episode 239/1000, Total Reward: -48.69, Epsilon: 0.302
# Episode 240/1000, Total Reward: -349.25, Epsilon: 0.300
# Episode 241/1000, Total Reward: -160.47, Epsilon: 0.299
# Episode 242/1000, Total Reward: -34.82, Epsilon: 0.297
# Episode 243/1000, Total Reward: -106.13, Epsilon: 0.296
# Episode 244/1000, Total Reward: -310.58, Epsilon: 0.294
# Episode 245/1000, Total Reward: -91.43, Epsilon: 0.293
# Episode 246/1000, Total Reward: -69.14, Epsilon: 0.291
# Episode 247/1000, Total Reward: -94.63, Epsilon: 0.290
# Episode 248/1000, Total Reward: -119.59, Epsilon: 0.288
# Episode 249/1000, Total Reward: 21.58, Epsilon: 0.287
# Episode 250/1000, Total Reward: -91.28, Epsilon: 0.286
# Episode 251/1000, Total Reward: -321.58, Epsilon: 0.284
# Episode 252/1000, Total Reward: -201.34, Epsilon: 0.283
# Episode 253/1000, Total Reward: -236.36, Epsilon: 0.281
# Episode 254/1000, Total Reward: -271.61, Epsilon: 0.280
# Episode 255/1000, Total Reward: -80.76, Epsilon: 0.279
# Episode 256/1000, Total Reward: -202.56, Epsilon: 0.277
# Episode 257/1000, Total Reward: -169.57, Epsilon: 0.276
# Episode 258/1000, Total Reward: -75.64, Epsilon: 0.274
# Episode 259/1000, Total Reward: -119.02, Epsilon: 0.273
# Episode 260/1000, Total Reward: -307.75, Epsilon: 0.272
# Episode 261/1000, Total Reward: -187.94, Epsilon: 0.270
# Episode 262/1000, Total Reward: -88.27, Epsilon: 0.269
# Episode 263/1000, Total Reward: -330.91, Epsilon: 0.268
# Episode 264/1000, Total Reward: -86.33, Epsilon: 0.266
# Episode 265/1000, Total Reward: -110.51, Epsilon: 0.265
# Episode 266/1000, Total Reward: -151.14, Epsilon: 0.264
# Episode 267/1000, Total Reward: -256.69, Epsilon: 0.262
# Episode 268/1000, Total Reward: -129.32, Epsilon: 0.261
# Episode 269/1000, Total Reward: -207.91, Epsilon: 0.260
# Episode 270/1000, Total Reward: -372.20, Epsilon: 0.258
# Episode 271/1000, Total Reward: -118.74, Epsilon: 0.257
# Episode 272/1000, Total Reward: -277.46, Epsilon: 0.256
# Episode 273/1000, Total Reward: -55.33, Epsilon: 0.255
# Episode 274/1000, Total Reward: -229.52, Epsilon: 0.253
# Episode 275/1000, Total Reward: -190.13, Epsilon: 0.252
# Episode 276/1000, Total Reward: -205.48, Epsilon: 0.251
# Episode 277/1000, Total Reward: -115.69, Epsilon: 0.249
# Episode 278/1000, Total Reward: -381.85, Epsilon: 0.248
# Episode 279/1000, Total Reward: -240.25, Epsilon: 0.247
# Episode 280/1000, Total Reward: -182.42, Epsilon: 0.246
# Episode 281/1000, Total Reward: -163.25, Epsilon: 0.245
# Episode 282/1000, Total Reward: -43.25, Epsilon: 0.243
# Episode 283/1000, Total Reward: -193.94, Epsilon: 0.242
# Episode 284/1000, Total Reward: -133.08, Epsilon: 0.241
# Episode 285/1000, Total Reward: -150.45, Epsilon: 0.240
# Episode 286/1000, Total Reward: -99.27, Epsilon: 0.238
# Episode 287/1000, Total Reward: -57.66, Epsilon: 0.237
# Episode 288/1000, Total Reward: -114.19, Epsilon: 0.236
# Episode 289/1000, Total Reward: -40.92, Epsilon: 0.235
# Episode 290/1000, Total Reward: -102.14, Epsilon: 0.234
# Episode 291/1000, Total Reward: -81.86, Epsilon: 0.233
# Episode 292/1000, Total Reward: -218.95, Epsilon: 0.231
# Episode 293/1000, Total Reward: -130.84, Epsilon: 0.230
# Episode 294/1000, Total Reward: -309.56, Epsilon: 0.229
# Episode 295/1000, Total Reward: -310.86, Epsilon: 0.228
# Episode 296/1000, Total Reward: -148.61, Epsilon: 0.227
# Episode 297/1000, Total Reward: -302.34, Epsilon: 0.226
# Episode 298/1000, Total Reward: -106.29, Epsilon: 0.225
# Episode 299/1000, Total Reward: -61.53, Epsilon: 0.223
# Episode 300/1000, Total Reward: -46.98, Epsilon: 0.222
# Episode 301/1000, Total Reward: -164.26, Epsilon: 0.221
# Episode 302/1000, Total Reward: -118.43, Epsilon: 0.220
# Episode 303/1000, Total Reward: -99.27, Epsilon: 0.219
# Episode 304/1000, Total Reward: -436.70, Epsilon: 0.218
# Episode 305/1000, Total Reward: -82.03, Epsilon: 0.217
# Episode 306/1000, Total Reward: -80.46, Epsilon: 0.216
# Episode 307/1000, Total Reward: -235.16, Epsilon: 0.215
# Episode 308/1000, Total Reward: -52.25, Epsilon: 0.214
# Episode 309/1000, Total Reward: -209.21, Epsilon: 0.212
# Episode 310/1000, Total Reward: -74.18, Epsilon: 0.211
# Episode 311/1000, Total Reward: -25.36, Epsilon: 0.210
# Episode 312/1000, Total Reward: -169.55, Epsilon: 0.209
# Episode 313/1000, Total Reward: -184.33, Epsilon: 0.208
# Episode 314/1000, Total Reward: -256.12, Epsilon: 0.207
# Episode 315/1000, Total Reward: -105.59, Epsilon: 0.206
# Episode 316/1000, Total Reward: -171.44, Epsilon: 0.205
# Episode 317/1000, Total Reward: -162.36, Epsilon: 0.204
# Episode 318/1000, Total Reward: -367.43, Epsilon: 0.203
# Episode 319/1000, Total Reward: -358.42, Epsilon: 0.202
# Episode 320/1000, Total Reward: -65.84, Epsilon: 0.201
# Episode 321/1000, Total Reward: -167.78, Epsilon: 0.200
# Episode 322/1000, Total Reward: -292.99, Epsilon: 0.199
# Episode 323/1000, Total Reward: -298.68, Epsilon: 0.198
# Episode 324/1000, Total Reward: -66.24, Epsilon: 0.197
# Episode 325/1000, Total Reward: -234.60, Epsilon: 0.196
# Episode 326/1000, Total Reward: -309.66, Epsilon: 0.195
# Episode 327/1000, Total Reward: -349.33, Epsilon: 0.194
# Episode 328/1000, Total Reward: -159.49, Epsilon: 0.193
# Episode 329/1000, Total Reward: -431.39, Epsilon: 0.192
# Episode 330/1000, Total Reward: -370.64, Epsilon: 0.191
# Episode 331/1000, Total Reward: -225.76, Epsilon: 0.190
# Episode 332/1000, Total Reward: -295.65, Epsilon: 0.189
# Episode 333/1000, Total Reward: -78.13, Epsilon: 0.188
# Episode 334/1000, Total Reward: -211.11, Epsilon: 0.187
# Episode 335/1000, Total Reward: -126.35, Epsilon: 0.187
# Episode 336/1000, Total Reward: -85.89, Epsilon: 0.186
# Episode 337/1000, Total Reward: -88.48, Epsilon: 0.185
# Episode 338/1000, Total Reward: -37.56, Epsilon: 0.184
# Episode 339/1000, Total Reward: -176.43, Epsilon: 0.183
# Episode 340/1000, Total Reward: -272.81, Epsilon: 0.182
# Episode 341/1000, Total Reward: -105.60, Epsilon: 0.181
# Episode 342/1000, Total Reward: -168.97, Epsilon: 0.180
# Episode 343/1000, Total Reward: -209.10, Epsilon: 0.179
# Episode 344/1000, Total Reward: -201.47, Epsilon: 0.178
# Episode 345/1000, Total Reward: -230.20, Epsilon: 0.177
# Episode 346/1000, Total Reward: -285.78, Epsilon: 0.177
# Episode 347/1000, Total Reward: -39.44, Epsilon: 0.176
# Episode 348/1000, Total Reward: -122.06, Epsilon: 0.175
# Episode 349/1000, Total Reward: -205.40, Epsilon: 0.174
# Episode 350/1000, Total Reward: -109.56, Epsilon: 0.173
# Episode 351/1000, Total Reward: -267.58, Epsilon: 0.172
# Episode 352/1000, Total Reward: -72.25, Epsilon: 0.171
# Episode 353/1000, Total Reward: -136.35, Epsilon: 0.170
# Episode 354/1000, Total Reward: -211.14, Epsilon: 0.170
# Episode 355/1000, Total Reward: 25.93, Epsilon: 0.169
# Episode 356/1000, Total Reward: -222.65, Epsilon: 0.168
# Episode 357/1000, Total Reward: 3.10, Epsilon: 0.167
# Episode 358/1000, Total Reward: -116.05, Epsilon: 0.166
# Episode 359/1000, Total Reward: -182.49, Epsilon: 0.165
# Episode 360/1000, Total Reward: 7.00, Epsilon: 0.165
# Episode 361/1000, Total Reward: -238.44, Epsilon: 0.164
# Episode 362/1000, Total Reward: -96.26, Epsilon: 0.163
# Episode 363/1000, Total Reward: -49.60, Epsilon: 0.162
# Episode 364/1000, Total Reward: -264.98, Epsilon: 0.161
# Episode 365/1000, Total Reward: -292.83, Epsilon: 0.160
# Episode 366/1000, Total Reward: -183.81, Epsilon: 0.160
# Episode 367/1000, Total Reward: -245.46, Epsilon: 0.159
# Episode 368/1000, Total Reward: -135.40, Epsilon: 0.158
# Episode 369/1000, Total Reward: -241.40, Epsilon: 0.157
# Episode 370/1000, Total Reward: -106.43, Epsilon: 0.157
# Episode 371/1000, Total Reward: -251.27, Epsilon: 0.156
# Episode 372/1000, Total Reward: -240.51, Epsilon: 0.155
# Episode 373/1000, Total Reward: -291.41, Epsilon: 0.154
# Episode 374/1000, Total Reward: -249.74, Epsilon: 0.153
# Episode 375/1000, Total Reward: -111.09, Epsilon: 0.153
# Episode 376/1000, Total Reward: 45.75, Epsilon: 0.152
# Episode 377/1000, Total Reward: -307.32, Epsilon: 0.151
# Episode 378/1000, Total Reward: -156.23, Epsilon: 0.150
# Episode 379/1000, Total Reward: -67.96, Epsilon: 0.150
# Episode 380/1000, Total Reward: 21.06, Epsilon: 0.149
# Episode 381/1000, Total Reward: -84.34, Epsilon: 0.148
# Episode 382/1000, Total Reward: -180.83, Epsilon: 0.147
# Episode 383/1000, Total Reward: -140.35, Epsilon: 0.147
# Episode 384/1000, Total Reward: -71.74, Epsilon: 0.146
# Episode 385/1000, Total Reward: -91.51, Epsilon: 0.145
# Episode 386/1000, Total Reward: -226.49, Epsilon: 0.144
# Episode 387/1000, Total Reward: -64.73, Epsilon: 0.144
# Episode 388/1000, Total Reward: -297.87, Epsilon: 0.143
# Episode 389/1000, Total Reward: -96.23, Epsilon: 0.142
# Episode 390/1000, Total Reward: -84.30, Epsilon: 0.142
# Episode 391/1000, Total Reward: -348.73, Epsilon: 0.141
# Episode 392/1000, Total Reward: -101.77, Epsilon: 0.140
# Episode 393/1000, Total Reward: -254.21, Epsilon: 0.139
# Episode 394/1000, Total Reward: -174.99, Epsilon: 0.139
# Episode 395/1000, Total Reward: -91.67, Epsilon: 0.138
# Episode 396/1000, Total Reward: -342.26, Epsilon: 0.137
# Episode 397/1000, Total Reward: -92.79, Epsilon: 0.137
# Episode 398/1000, Total Reward: -211.62, Epsilon: 0.136
# Episode 399/1000, Total Reward: -297.86, Epsilon: 0.135
# Episode 400/1000, Total Reward: -120.16, Epsilon: 0.135
# Episode 401/1000, Total Reward: -89.77, Epsilon: 0.134
# Episode 402/1000, Total Reward: -287.89, Epsilon: 0.133
# Episode 403/1000, Total Reward: -270.20, Epsilon: 0.133
# Episode 404/1000, Total Reward: -90.47, Epsilon: 0.132
# Episode 405/1000, Total Reward: -117.55, Epsilon: 0.131
# Episode 406/1000, Total Reward: -178.00, Epsilon: 0.131
# Episode 407/1000, Total Reward: -129.56, Epsilon: 0.130
# Episode 408/1000, Total Reward: -89.10, Epsilon: 0.129
# Episode 409/1000, Total Reward: -158.03, Epsilon: 0.129
# Episode 410/1000, Total Reward: -36.61, Epsilon: 0.128
# Episode 411/1000, Total Reward: -103.55, Epsilon: 0.127
# Episode 412/1000, Total Reward: -76.88, Epsilon: 0.127
# Episode 413/1000, Total Reward: -190.07, Epsilon: 0.126
# Episode 414/1000, Total Reward: -290.44, Epsilon: 0.126
# Episode 415/1000, Total Reward: -135.67, Epsilon: 0.125
# Episode 416/1000, Total Reward: -194.84, Epsilon: 0.124
# Episode 417/1000, Total Reward: -253.26, Epsilon: 0.124
# Episode 418/1000, Total Reward: -70.31, Epsilon: 0.123
# Episode 419/1000, Total Reward: -263.14, Epsilon: 0.122
# Episode 420/1000, Total Reward: -134.11, Epsilon: 0.122
# Episode 421/1000, Total Reward: -77.25, Epsilon: 0.121
# Episode 422/1000, Total Reward: -119.88, Epsilon: 0.121
# Episode 423/1000, Total Reward: -101.95, Epsilon: 0.120
# Episode 424/1000, Total Reward: -100.07, Epsilon: 0.119
# Episode 425/1000, Total Reward: -108.41, Epsilon: 0.119
# Episode 426/1000, Total Reward: -192.70, Epsilon: 0.118
# Episode 427/1000, Total Reward: -66.73, Epsilon: 0.118
# Episode 428/1000, Total Reward: -88.53, Epsilon: 0.117
# Episode 429/1000, Total Reward: -152.53, Epsilon: 0.116
# Episode 430/1000, Total Reward: -73.72, Epsilon: 0.116
# Episode 431/1000, Total Reward: -102.31, Epsilon: 0.115
# Episode 432/1000, Total Reward: -231.51, Epsilon: 0.115
# Episode 433/1000, Total Reward: -103.31, Epsilon: 0.114
# Episode 434/1000, Total Reward: -75.18, Epsilon: 0.114
# Episode 435/1000, Total Reward: -261.24, Epsilon: 0.113
# Episode 436/1000, Total Reward: -214.34, Epsilon: 0.112
# Episode 437/1000, Total Reward: -74.86, Epsilon: 0.112
# Episode 438/1000, Total Reward: -84.90, Epsilon: 0.111
# Episode 439/1000, Total Reward: -198.98, Epsilon: 0.111
# Episode 440/1000, Total Reward: 3.30, Epsilon: 0.110
# Episode 441/1000, Total Reward: -272.09, Epsilon: 0.110
# Episode 442/1000, Total Reward: -64.26, Epsilon: 0.109
# Episode 443/1000, Total Reward: -181.41, Epsilon: 0.109
# Episode 444/1000, Total Reward: -428.06, Epsilon: 0.108
# Episode 445/1000, Total Reward: -364.44, Epsilon: 0.107
# Episode 446/1000, Total Reward: -106.67, Epsilon: 0.107
# Episode 447/1000, Total Reward: -352.24, Epsilon: 0.106
# Episode 448/1000, Total Reward: -241.30, Epsilon: 0.106
# Episode 449/1000, Total Reward: -65.85, Epsilon: 0.105
# Episode 450/1000, Total Reward: -176.70, Epsilon: 0.105
# Episode 451/1000, Total Reward: -83.93, Epsilon: 0.104
# Episode 452/1000, Total Reward: -306.08, Epsilon: 0.104
# Episode 453/1000, Total Reward: -430.81, Epsilon: 0.103
# Episode 454/1000, Total Reward: -127.00, Epsilon: 0.103
# Episode 455/1000, Total Reward: -110.00, Epsilon: 0.102
# Episode 456/1000, Total Reward: -374.43, Epsilon: 0.102
# Episode 457/1000, Total Reward: -90.86, Epsilon: 0.101
# Episode 458/1000, Total Reward: -10.87, Epsilon: 0.101
# Episode 459/1000, Total Reward: -239.65, Epsilon: 0.100
# Episode 460/1000, Total Reward: -290.20, Epsilon: 0.100
# Episode 461/1000, Total Reward: -205.31, Epsilon: 0.099
# Episode 462/1000, Total Reward: -141.88, Epsilon: 0.099
# Episode 463/1000, Total Reward: -285.86, Epsilon: 0.098
# Episode 464/1000, Total Reward: -66.78, Epsilon: 0.098
# Episode 465/1000, Total Reward: -10.87, Epsilon: 0.097
# Episode 466/1000, Total Reward: -238.73, Epsilon: 0.097
# Episode 467/1000, Total Reward: -217.96, Epsilon: 0.096
# Episode 468/1000, Total Reward: -222.24, Epsilon: 0.096
# Episode 469/1000, Total Reward: -194.37, Epsilon: 0.095
# Episode 470/1000, Total Reward: -260.89, Epsilon: 0.095
# Episode 471/1000, Total Reward: -228.93, Epsilon: 0.094
# Episode 472/1000, Total Reward: -188.71, Epsilon: 0.094
# Episode 473/1000, Total Reward: -306.47, Epsilon: 0.093
# Episode 474/1000, Total Reward: -304.76, Epsilon: 0.093
# Episode 475/1000, Total Reward: -83.51, Epsilon: 0.092
# Episode 476/1000, Total Reward: -267.05, Epsilon: 0.092
# Episode 477/1000, Total Reward: -202.61, Epsilon: 0.092
# Episode 478/1000, Total Reward: -230.48, Epsilon: 0.091
# Episode 479/1000, Total Reward: -32.72, Epsilon: 0.091
# Episode 480/1000, Total Reward: -228.50, Epsilon: 0.090
# Episode 481/1000, Total Reward: -159.10, Epsilon: 0.090
# Episode 482/1000, Total Reward: -94.85, Epsilon: 0.089
# Episode 483/1000, Total Reward: -315.73, Epsilon: 0.089
# Episode 484/1000, Total Reward: -126.71, Epsilon: 0.088
# Episode 485/1000, Total Reward: -133.55, Epsilon: 0.088
# Episode 486/1000, Total Reward: -274.12, Epsilon: 0.088
# Episode 487/1000, Total Reward: -325.38, Epsilon: 0.087
# Episode 488/1000, Total Reward: -77.47, Epsilon: 0.087
# Episode 489/1000, Total Reward: -336.89, Epsilon: 0.086
# Episode 490/1000, Total Reward: -68.38, Epsilon: 0.086
# Episode 491/1000, Total Reward: -149.80, Epsilon: 0.085
# Episode 492/1000, Total Reward: -304.29, Epsilon: 0.085
# Episode 493/1000, Total Reward: -214.98, Epsilon: 0.084
# Episode 494/1000, Total Reward: -104.54, Epsilon: 0.084
# Episode 495/1000, Total Reward: -92.90, Epsilon: 0.084
# Episode 496/1000, Total Reward: -227.96, Epsilon: 0.083
# Episode 497/1000, Total Reward: -330.41, Epsilon: 0.083
# Episode 498/1000, Total Reward: -198.35, Epsilon: 0.082
# Episode 499/1000, Total Reward: -110.74, Epsilon: 0.082
# Episode 500/1000, Total Reward: -193.42, Epsilon: 0.082
# Episode 501/1000, Total Reward: -169.23, Epsilon: 0.081
# Episode 502/1000, Total Reward: -291.69, Epsilon: 0.081
# Episode 503/1000, Total Reward: -79.37, Epsilon: 0.080
# Episode 504/1000, Total Reward: -246.78, Epsilon: 0.080
# Episode 505/1000, Total Reward: -245.59, Epsilon: 0.080
# Episode 506/1000, Total Reward: -20.34, Epsilon: 0.079
# Episode 507/1000, Total Reward: -52.70, Epsilon: 0.079
# Episode 508/1000, Total Reward: -248.46, Epsilon: 0.078
# Episode 509/1000, Total Reward: -258.70, Epsilon: 0.078
# Episode 510/1000, Total Reward: -91.16, Epsilon: 0.078
# Episode 511/1000, Total Reward: -112.56, Epsilon: 0.077
# Episode 512/1000, Total Reward: -113.62, Epsilon: 0.077
# Episode 513/1000, Total Reward: -13.48, Epsilon: 0.076
# Episode 514/1000, Total Reward: -79.65, Epsilon: 0.076
# Episode 515/1000, Total Reward: -153.93, Epsilon: 0.076
# Episode 516/1000, Total Reward: -106.01, Epsilon: 0.075
# Episode 517/1000, Total Reward: -97.20, Epsilon: 0.075
# Episode 518/1000, Total Reward: -154.06, Epsilon: 0.075
# Episode 519/1000, Total Reward: -247.87, Epsilon: 0.074
# Episode 520/1000, Total Reward: -205.80, Epsilon: 0.074
# Episode 521/1000, Total Reward: 8.90, Epsilon: 0.073
# Episode 522/1000, Total Reward: -82.53, Epsilon: 0.073
# Episode 523/1000, Total Reward: -55.14, Epsilon: 0.073
# Episode 524/1000, Total Reward: -56.95, Epsilon: 0.072
# Episode 525/1000, Total Reward: -187.75, Epsilon: 0.072
# Episode 526/1000, Total Reward: -98.49, Epsilon: 0.072
# Episode 527/1000, Total Reward: -191.92, Epsilon: 0.071
# Episode 528/1000, Total Reward: -162.14, Epsilon: 0.071
# Episode 529/1000, Total Reward: -42.27, Epsilon: 0.071
# Episode 530/1000, Total Reward: -321.51, Epsilon: 0.070
# Episode 531/1000, Total Reward: -264.65, Epsilon: 0.070
# Episode 532/1000, Total Reward: -76.85, Epsilon: 0.069
# Episode 533/1000, Total Reward: -97.38, Epsilon: 0.069
# Episode 534/1000, Total Reward: -161.89, Epsilon: 0.069
# Episode 535/1000, Total Reward: -249.44, Epsilon: 0.068
# Episode 536/1000, Total Reward: -7.46, Epsilon: 0.068
# Episode 537/1000, Total Reward: -106.62, Epsilon: 0.068
# Episode 538/1000, Total Reward: -138.73, Epsilon: 0.067
# Episode 539/1000, Total Reward: -102.23, Epsilon: 0.067
# Episode 540/1000, Total Reward: 3.42, Epsilon: 0.067
# Episode 541/1000, Total Reward: -226.99, Epsilon: 0.066
# Episode 542/1000, Total Reward: -288.84, Epsilon: 0.066
# Episode 543/1000, Total Reward: -225.05, Epsilon: 0.066
# Episode 544/1000, Total Reward: -188.42, Epsilon: 0.065
# Episode 545/1000, Total Reward: -215.57, Epsilon: 0.065
# Episode 546/1000, Total Reward: -129.17, Epsilon: 0.065
# Episode 547/1000, Total Reward: -252.81, Epsilon: 0.064
# Episode 548/1000, Total Reward: -358.22, Epsilon: 0.064
# Episode 549/1000, Total Reward: -128.02, Epsilon: 0.064
# Episode 550/1000, Total Reward: -225.07, Epsilon: 0.063
# Episode 551/1000, Total Reward: -144.64, Epsilon: 0.063
# Episode 552/1000, Total Reward: -202.59, Epsilon: 0.063
# Episode 553/1000, Total Reward: 20.25, Epsilon: 0.063
# Episode 554/1000, Total Reward: -189.27, Epsilon: 0.062
# Episode 555/1000, Total Reward: -248.18, Epsilon: 0.062
# Episode 556/1000, Total Reward: -147.81, Epsilon: 0.062
# Episode 557/1000, Total Reward: -89.27, Epsilon: 0.061
# Episode 558/1000, Total Reward: -208.83, Epsilon: 0.061
# Episode 559/1000, Total Reward: -301.77, Epsilon: 0.061
# Episode 560/1000, Total Reward: -179.72, Epsilon: 0.060
# Episode 561/1000, Total Reward: -286.57, Epsilon: 0.060
# Episode 562/1000, Total Reward: -95.15, Epsilon: 0.060
# Episode 563/1000, Total Reward: -242.47, Epsilon: 0.059
# Episode 564/1000, Total Reward: -157.30, Epsilon: 0.059
# Episode 565/1000, Total Reward: -113.49, Epsilon: 0.059
# Episode 566/1000, Total Reward: -212.81, Epsilon: 0.059
# Episode 567/1000, Total Reward: -276.61, Epsilon: 0.058
# Episode 568/1000, Total Reward: -192.62, Epsilon: 0.058
# Episode 569/1000, Total Reward: -157.11, Epsilon: 0.058
# Episode 570/1000, Total Reward: -328.70, Epsilon: 0.057
# Episode 571/1000, Total Reward: -115.42, Epsilon: 0.057
# Episode 572/1000, Total Reward: -294.87, Epsilon: 0.057
# Episode 573/1000, Total Reward: 11.09, Epsilon: 0.057
# Episode 574/1000, Total Reward: -193.69, Epsilon: 0.056
# Episode 575/1000, Total Reward: -131.49, Epsilon: 0.056
# Episode 576/1000, Total Reward: -188.26, Epsilon: 0.056
# Episode 577/1000, Total Reward: -273.93, Epsilon: 0.055
# Episode 578/1000, Total Reward: -40.46, Epsilon: 0.055
# Episode 579/1000, Total Reward: -117.23, Epsilon: 0.055
# Episode 580/1000, Total Reward: -179.02, Epsilon: 0.055
# Episode 581/1000, Total Reward: -93.84, Epsilon: 0.054
# Episode 582/1000, Total Reward: -40.74, Epsilon: 0.054
# Episode 583/1000, Total Reward: -184.18, Epsilon: 0.054
# Episode 584/1000, Total Reward: -379.21, Epsilon: 0.054
# Episode 585/1000, Total Reward: -176.94, Epsilon: 0.053
# Episode 586/1000, Total Reward: -229.99, Epsilon: 0.053
# Episode 587/1000, Total Reward: -259.34, Epsilon: 0.053
# Episode 588/1000, Total Reward: -250.76, Epsilon: 0.052
# Episode 589/1000, Total Reward: -180.28, Epsilon: 0.052
# Episode 590/1000, Total Reward: -354.32, Epsilon: 0.052
# Episode 591/1000, Total Reward: -75.44, Epsilon: 0.052
# Episode 592/1000, Total Reward: -278.58, Epsilon: 0.051
# Episode 593/1000, Total Reward: -110.34, Epsilon: 0.051
# Episode 594/1000, Total Reward: -63.22, Epsilon: 0.051
# Episode 595/1000, Total Reward: -225.24, Epsilon: 0.051
# Episode 596/1000, Total Reward: -69.68, Epsilon: 0.050
# Episode 597/1000, Total Reward: -101.93, Epsilon: 0.050
# Episode 598/1000, Total Reward: -83.56, Epsilon: 0.050
# Episode 599/1000, Total Reward: -101.43, Epsilon: 0.050
# Episode 600/1000, Total Reward: -214.34, Epsilon: 0.049
# Episode 601/1000, Total Reward: -115.25, Epsilon: 0.049
# Episode 602/1000, Total Reward: -94.54, Epsilon: 0.049
# Episode 603/1000, Total Reward: -26.77, Epsilon: 0.049
# Episode 604/1000, Total Reward: -310.44, Epsilon: 0.048
# Episode 605/1000, Total Reward: -114.17, Epsilon: 0.048
# Episode 606/1000, Total Reward: -82.50, Epsilon: 0.048
# Episode 607/1000, Total Reward: -66.19, Epsilon: 0.048
# Episode 608/1000, Total Reward: -72.56, Epsilon: 0.047
# Episode 609/1000, Total Reward: -224.08, Epsilon: 0.047
# Episode 610/1000, Total Reward: -100.39, Epsilon: 0.047
# Episode 611/1000, Total Reward: -326.78, Epsilon: 0.047
# Episode 612/1000, Total Reward: -212.85, Epsilon: 0.047
# Episode 613/1000, Total Reward: -81.96, Epsilon: 0.046
# Episode 614/1000, Total Reward: -77.89, Epsilon: 0.046
# Episode 615/1000, Total Reward: -63.95, Epsilon: 0.046
# Episode 616/1000, Total Reward: -428.87, Epsilon: 0.046
# Episode 617/1000, Total Reward: -358.95, Epsilon: 0.045
# Episode 618/1000, Total Reward: -365.10, Epsilon: 0.045
# Episode 619/1000, Total Reward: -77.67, Epsilon: 0.045
# Episode 620/1000, Total Reward: -252.96, Epsilon: 0.045
# Episode 621/1000, Total Reward: -196.77, Epsilon: 0.044
# Episode 622/1000, Total Reward: -235.87, Epsilon: 0.044
# Episode 623/1000, Total Reward: -198.19, Epsilon: 0.044
# Episode 624/1000, Total Reward: -178.39, Epsilon: 0.044
# Episode 625/1000, Total Reward: -243.49, Epsilon: 0.044
# Episode 626/1000, Total Reward: -149.46, Epsilon: 0.043
# Episode 627/1000, Total Reward: -95.74, Epsilon: 0.043
# Episode 628/1000, Total Reward: -87.53, Epsilon: 0.043
# Episode 629/1000, Total Reward: -137.92, Epsilon: 0.043
# Episode 630/1000, Total Reward: -18.35, Epsilon: 0.043
# Episode 631/1000, Total Reward: -99.01, Epsilon: 0.042
# Episode 632/1000, Total Reward: -262.38, Epsilon: 0.042
# Episode 633/1000, Total Reward: -197.44, Epsilon: 0.042
# Episode 634/1000, Total Reward: -213.11, Epsilon: 0.042
# Episode 635/1000, Total Reward: -128.43, Epsilon: 0.041
# Episode 636/1000, Total Reward: -131.20, Epsilon: 0.041
# Episode 637/1000, Total Reward: -179.50, Epsilon: 0.041
# Episode 638/1000, Total Reward: -214.16, Epsilon: 0.041
# Episode 639/1000, Total Reward: -172.99, Epsilon: 0.041
# Episode 640/1000, Total Reward: -63.36, Epsilon: 0.040
# Episode 641/1000, Total Reward: -299.11, Epsilon: 0.040
# Episode 642/1000, Total Reward: -85.49, Epsilon: 0.040
# Episode 643/1000, Total Reward: -282.04, Epsilon: 0.040
# Episode 644/1000, Total Reward: -159.40, Epsilon: 0.040
# Episode 645/1000, Total Reward: -48.56, Epsilon: 0.039
# Episode 646/1000, Total Reward: 28.51, Epsilon: 0.039
# Episode 647/1000, Total Reward: -221.27, Epsilon: 0.039
# Episode 648/1000, Total Reward: -56.43, Epsilon: 0.039
# Episode 649/1000, Total Reward: -65.07, Epsilon: 0.039
# Episode 650/1000, Total Reward: -282.64, Epsilon: 0.038
# Episode 651/1000, Total Reward: -110.12, Epsilon: 0.038
# Episode 652/1000, Total Reward: -87.98, Epsilon: 0.038
# Episode 653/1000, Total Reward: -218.31, Epsilon: 0.038
# Episode 654/1000, Total Reward: -249.56, Epsilon: 0.038
# Episode 655/1000, Total Reward: -359.76, Epsilon: 0.038
# Episode 656/1000, Total Reward: -105.55, Epsilon: 0.037
# Episode 657/1000, Total Reward: -336.86, Epsilon: 0.037
# Episode 658/1000, Total Reward: -135.88, Epsilon: 0.037
# Episode 659/1000, Total Reward: -32.50, Epsilon: 0.037
# Episode 660/1000, Total Reward: -80.94, Epsilon: 0.037
# Episode 661/1000, Total Reward: -105.22, Epsilon: 0.036
# Episode 662/1000, Total Reward: -119.49, Epsilon: 0.036
# Episode 663/1000, Total Reward: -114.07, Epsilon: 0.036
# Episode 664/1000, Total Reward: -243.59, Epsilon: 0.036
# Episode 665/1000, Total Reward: -120.53, Epsilon: 0.036
# Episode 666/1000, Total Reward: -152.99, Epsilon: 0.035
# Episode 667/1000, Total Reward: -364.83, Epsilon: 0.035
# Episode 668/1000, Total Reward: -198.13, Epsilon: 0.035
# Episode 669/1000, Total Reward: -24.12, Epsilon: 0.035
# Episode 670/1000, Total Reward: -229.51, Epsilon: 0.035
# Episode 671/1000, Total Reward: -112.22, Epsilon: 0.035
# Episode 672/1000, Total Reward: -86.35, Epsilon: 0.034
# Episode 673/1000, Total Reward: -145.07, Epsilon: 0.034
# Episode 674/1000, Total Reward: -327.03, Epsilon: 0.034
# Episode 675/1000, Total Reward: -84.93, Epsilon: 0.034
# Episode 676/1000, Total Reward: -198.40, Epsilon: 0.034
# Episode 677/1000, Total Reward: -202.23, Epsilon: 0.034
# Episode 678/1000, Total Reward: -143.74, Epsilon: 0.033
# Episode 679/1000, Total Reward: -350.76, Epsilon: 0.033
# Episode 680/1000, Total Reward: -329.11, Epsilon: 0.033
# Episode 681/1000, Total Reward: -280.57, Epsilon: 0.033
# Episode 682/1000, Total Reward: -106.39, Epsilon: 0.033
# Episode 683/1000, Total Reward: -77.60, Epsilon: 0.033
# Episode 684/1000, Total Reward: -64.03, Epsilon: 0.032
# Episode 685/1000, Total Reward: -234.51, Epsilon: 0.032
# Episode 686/1000, Total Reward: -210.72, Epsilon: 0.032
# Episode 687/1000, Total Reward: -69.37, Epsilon: 0.032
# Episode 688/1000, Total Reward: -95.54, Epsilon: 0.032
# Episode 689/1000, Total Reward: -18.32, Epsilon: 0.032
# Episode 690/1000, Total Reward: -175.06, Epsilon: 0.031
# Episode 691/1000, Total Reward: -55.15, Epsilon: 0.031
# Episode 692/1000, Total Reward: -91.14, Epsilon: 0.031
# Episode 693/1000, Total Reward: -182.60, Epsilon: 0.031
# Episode 694/1000, Total Reward: -144.73, Epsilon: 0.031
# Episode 695/1000, Total Reward: -253.28, Epsilon: 0.031
# Episode 696/1000, Total Reward: -83.31, Epsilon: 0.031
# Episode 697/1000, Total Reward: -65.16, Epsilon: 0.030
# Episode 698/1000, Total Reward: -229.12, Epsilon: 0.030
# Episode 699/1000, Total Reward: -93.98, Epsilon: 0.030
# Episode 700/1000, Total Reward: -266.42, Epsilon: 0.030
# Episode 701/1000, Total Reward: -284.92, Epsilon: 0.030
# Episode 702/1000, Total Reward: -260.77, Epsilon: 0.030
# Episode 703/1000, Total Reward: -106.90, Epsilon: 0.029
# Episode 704/1000, Total Reward: -158.23, Epsilon: 0.029
# Episode 705/1000, Total Reward: -297.38, Epsilon: 0.029
# Episode 706/1000, Total Reward: -204.30, Epsilon: 0.029
# Episode 707/1000, Total Reward: -72.20, Epsilon: 0.029
# Episode 708/1000, Total Reward: -235.90, Epsilon: 0.029
# Episode 709/1000, Total Reward: -95.48, Epsilon: 0.029
# Episode 710/1000, Total Reward: -123.20, Epsilon: 0.028
# Episode 711/1000, Total Reward: -307.93, Epsilon: 0.028
# Episode 712/1000, Total Reward: -119.78, Epsilon: 0.028
# Episode 713/1000, Total Reward: -226.71, Epsilon: 0.028
# Episode 714/1000, Total Reward: -218.58, Epsilon: 0.028
# Episode 715/1000, Total Reward: -72.35, Epsilon: 0.028
# Episode 716/1000, Total Reward: -90.69, Epsilon: 0.028
# Episode 717/1000, Total Reward: -41.15, Epsilon: 0.027
# Episode 718/1000, Total Reward: -415.74, Epsilon: 0.027
# Episode 719/1000, Total Reward: -201.18, Epsilon: 0.027
# Episode 720/1000, Total Reward: -129.52, Epsilon: 0.027
# Episode 721/1000, Total Reward: -3.42, Epsilon: 0.027
# Episode 722/1000, Total Reward: -56.95, Epsilon: 0.027
# Episode 723/1000, Total Reward: -203.84, Epsilon: 0.027
# Episode 724/1000, Total Reward: -322.92, Epsilon: 0.027
# Episode 725/1000, Total Reward: -46.65, Epsilon: 0.026
# Episode 726/1000, Total Reward: -198.10, Epsilon: 0.026
# Episode 727/1000, Total Reward: -15.24, Epsilon: 0.026
# Episode 728/1000, Total Reward: -174.26, Epsilon: 0.026
# Episode 729/1000, Total Reward: -141.64, Epsilon: 0.026
# Episode 730/1000, Total Reward: -175.56, Epsilon: 0.026
# Episode 731/1000, Total Reward: -147.43, Epsilon: 0.026
# Episode 732/1000, Total Reward: -116.27, Epsilon: 0.025
# Episode 733/1000, Total Reward: -272.13, Epsilon: 0.025
# Episode 734/1000, Total Reward: -97.70, Epsilon: 0.025
# Episode 735/1000, Total Reward: -204.11, Epsilon: 0.025
# Episode 736/1000, Total Reward: -121.69, Epsilon: 0.025
# Episode 737/1000, Total Reward: -89.48, Epsilon: 0.025
# Episode 738/1000, Total Reward: -275.09, Epsilon: 0.025
# Episode 739/1000, Total Reward: -146.82, Epsilon: 0.025
# Episode 740/1000, Total Reward: -276.35, Epsilon: 0.024
# Episode 741/1000, Total Reward: -294.03, Epsilon: 0.024
# Episode 742/1000, Total Reward: -54.99, Epsilon: 0.024
# Episode 743/1000, Total Reward: -108.93, Epsilon: 0.024
# Episode 744/1000, Total Reward: -86.04, Epsilon: 0.024
# Episode 745/1000, Total Reward: -134.61, Epsilon: 0.024
# Episode 746/1000, Total Reward: -97.15, Epsilon: 0.024
# Episode 747/1000, Total Reward: -90.62, Epsilon: 0.024
# Episode 748/1000, Total Reward: -133.27, Epsilon: 0.024
# Episode 749/1000, Total Reward: -186.19, Epsilon: 0.023
# Episode 750/1000, Total Reward: -22.24, Epsilon: 0.023
# Episode 751/1000, Total Reward: -214.57, Epsilon: 0.023
# Episode 752/1000, Total Reward: -123.22, Epsilon: 0.023
# Episode 753/1000, Total Reward: -127.04, Epsilon: 0.023
# Episode 754/1000, Total Reward: -450.71, Epsilon: 0.023
# Episode 755/1000, Total Reward: -184.20, Epsilon: 0.023
# Episode 756/1000, Total Reward: -200.92, Epsilon: 0.023
# Episode 757/1000, Total Reward: -190.26, Epsilon: 0.022
# Episode 758/1000, Total Reward: -22.09, Epsilon: 0.022
# Episode 759/1000, Total Reward: -230.92, Epsilon: 0.022
# Episode 760/1000, Total Reward: -189.98, Epsilon: 0.022
# Episode 761/1000, Total Reward: -14.69, Epsilon: 0.022
# Episode 762/1000, Total Reward: -244.26, Epsilon: 0.022
# Episode 763/1000, Total Reward: -207.83, Epsilon: 0.022
# Episode 764/1000, Total Reward: -56.29, Epsilon: 0.022
# Episode 765/1000, Total Reward: -346.79, Epsilon: 0.022
# Episode 766/1000, Total Reward: -87.32, Epsilon: 0.022
# Episode 767/1000, Total Reward: -353.19, Epsilon: 0.021
# Episode 768/1000, Total Reward: -115.62, Epsilon: 0.021
# Episode 769/1000, Total Reward: -251.16, Epsilon: 0.021
# Episode 770/1000, Total Reward: -68.35, Epsilon: 0.021
# Episode 771/1000, Total Reward: -17.06, Epsilon: 0.021
# Episode 772/1000, Total Reward: -97.37, Epsilon: 0.021
# Episode 773/1000, Total Reward: 10.42, Epsilon: 0.021
# Episode 774/1000, Total Reward: 0.32, Epsilon: 0.021
# Episode 775/1000, Total Reward: -234.77, Epsilon: 0.021
# Episode 776/1000, Total Reward: -59.94, Epsilon: 0.020
# Episode 777/1000, Total Reward: -112.92, Epsilon: 0.020
# Episode 778/1000, Total Reward: -152.75, Epsilon: 0.020
# Episode 779/1000, Total Reward: -250.38, Epsilon: 0.020
# Episode 780/1000, Total Reward: -79.07, Epsilon: 0.020
# Episode 781/1000, Total Reward: -114.29, Epsilon: 0.020
# Episode 782/1000, Total Reward: -250.17, Epsilon: 0.020
# Episode 783/1000, Total Reward: -204.81, Epsilon: 0.020
# Episode 784/1000, Total Reward: -167.85, Epsilon: 0.020
# Episode 785/1000, Total Reward: -196.40, Epsilon: 0.020
# Episode 786/1000, Total Reward: -43.54, Epsilon: 0.019
# Episode 787/1000, Total Reward: 31.84, Epsilon: 0.019
# Episode 788/1000, Total Reward: -331.60, Epsilon: 0.019
# Episode 789/1000, Total Reward: -266.01, Epsilon: 0.019
# Episode 790/1000, Total Reward: -246.86, Epsilon: 0.019
# Episode 791/1000, Total Reward: -27.55, Epsilon: 0.019
# Episode 792/1000, Total Reward: -73.25, Epsilon: 0.019
# Episode 793/1000, Total Reward: -85.62, Epsilon: 0.019
# Episode 794/1000, Total Reward: -164.86, Epsilon: 0.019
# Episode 795/1000, Total Reward: -203.19, Epsilon: 0.019
# Episode 796/1000, Total Reward: -96.99, Epsilon: 0.019
# Episode 797/1000, Total Reward: -135.61, Epsilon: 0.018
# Episode 798/1000, Total Reward: -121.47, Epsilon: 0.018
# Episode 799/1000, Total Reward: -58.20, Epsilon: 0.018
# Episode 800/1000, Total Reward: -34.36, Epsilon: 0.018
# Episode 801/1000, Total Reward: -396.11, Epsilon: 0.018
# Episode 802/1000, Total Reward: -163.02, Epsilon: 0.018
# Episode 803/1000, Total Reward: -249.22, Epsilon: 0.018
# Episode 804/1000, Total Reward: -71.81, Epsilon: 0.018
# Episode 805/1000, Total Reward: -195.88, Epsilon: 0.018
# Episode 806/1000, Total Reward: -68.82, Epsilon: 0.018
# Episode 807/1000, Total Reward: -334.08, Epsilon: 0.018
# Episode 808/1000, Total Reward: -107.36, Epsilon: 0.017
# Episode 809/1000, Total Reward: -109.22, Epsilon: 0.017
# Episode 810/1000, Total Reward: -199.04, Epsilon: 0.017
# Episode 811/1000, Total Reward: -92.26, Epsilon: 0.017
# Episode 812/1000, Total Reward: -102.24, Epsilon: 0.017
# Episode 813/1000, Total Reward: -204.93, Epsilon: 0.017
# Episode 814/1000, Total Reward: -268.91, Epsilon: 0.017
# Episode 815/1000, Total Reward: -93.85, Epsilon: 0.017
# Episode 816/1000, Total Reward: -413.22, Epsilon: 0.017
# Episode 817/1000, Total Reward: -265.31, Epsilon: 0.017
# Episode 818/1000, Total Reward: -62.11, Epsilon: 0.017
# Episode 819/1000, Total Reward: -61.95, Epsilon: 0.016
# Episode 820/1000, Total Reward: -75.55, Epsilon: 0.016
# Episode 821/1000, Total Reward: -277.75, Epsilon: 0.016
# Episode 822/1000, Total Reward: -183.72, Epsilon: 0.016
# Episode 823/1000, Total Reward: -312.95, Epsilon: 0.016
# Episode 824/1000, Total Reward: -133.08, Epsilon: 0.016
# Episode 825/1000, Total Reward: -124.26, Epsilon: 0.016
# Episode 826/1000, Total Reward: -149.27, Epsilon: 0.016
# Episode 827/1000, Total Reward: -333.24, Epsilon: 0.016
# Episode 828/1000, Total Reward: -231.84, Epsilon: 0.016
# Episode 829/1000, Total Reward: -37.08, Epsilon: 0.016
# Episode 830/1000, Total Reward: -91.85, Epsilon: 0.016
# Episode 831/1000, Total Reward: -325.43, Epsilon: 0.016
# Episode 832/1000, Total Reward: -202.85, Epsilon: 0.015
# Episode 833/1000, Total Reward: -62.19, Epsilon: 0.015
# Episode 834/1000, Total Reward: -235.41, Epsilon: 0.015
# Episode 835/1000, Total Reward: -153.11, Epsilon: 0.015
# Episode 836/1000, Total Reward: -49.25, Epsilon: 0.015
# Episode 837/1000, Total Reward: -242.63, Epsilon: 0.015
# Episode 838/1000, Total Reward: -99.48, Epsilon: 0.015
# Episode 839/1000, Total Reward: -3.42, Epsilon: 0.015
# Episode 840/1000, Total Reward: -102.94, Epsilon: 0.015
# Episode 841/1000, Total Reward: -95.16, Epsilon: 0.015
# Episode 842/1000, Total Reward: -97.18, Epsilon: 0.015
# Episode 843/1000, Total Reward: -54.13, Epsilon: 0.015
# Episode 844/1000, Total Reward: -147.94, Epsilon: 0.015
# Episode 845/1000, Total Reward: -126.96, Epsilon: 0.014
# Episode 846/1000, Total Reward: -122.30, Epsilon: 0.014
# Episode 847/1000, Total Reward: -101.13, Epsilon: 0.014
# Episode 848/1000, Total Reward: -11.06, Epsilon: 0.014
# Episode 849/1000, Total Reward: -223.31, Epsilon: 0.014
# Episode 850/1000, Total Reward: -271.22, Epsilon: 0.014
# Episode 851/1000, Total Reward: -260.56, Epsilon: 0.014
# Episode 852/1000, Total Reward: -94.31, Epsilon: 0.014
# Episode 853/1000, Total Reward: -244.22, Epsilon: 0.014
# Episode 854/1000, Total Reward: -175.65, Epsilon: 0.014
# Episode 855/1000, Total Reward: -90.61, Epsilon: 0.014
# Episode 856/1000, Total Reward: -50.50, Epsilon: 0.014
# Episode 857/1000, Total Reward: -121.51, Epsilon: 0.014
# Episode 858/1000, Total Reward: -116.80, Epsilon: 0.014
# Episode 859/1000, Total Reward: -254.65, Epsilon: 0.013
# Episode 860/1000, Total Reward: -293.32, Epsilon: 0.013
# Episode 861/1000, Total Reward: -198.57, Epsilon: 0.013
# Episode 862/1000, Total Reward: -208.12, Epsilon: 0.013
# Episode 863/1000, Total Reward: -114.99, Epsilon: 0.013
# Episode 864/1000, Total Reward: -209.07, Epsilon: 0.013
# Episode 865/1000, Total Reward: -270.67, Epsilon: 0.013
# Episode 866/1000, Total Reward: -89.93, Epsilon: 0.013
# Episode 867/1000, Total Reward: -37.41, Epsilon: 0.013
# Episode 868/1000, Total Reward: -210.51, Epsilon: 0.013
# Episode 869/1000, Total Reward: -108.58, Epsilon: 0.013
# Episode 870/1000, Total Reward: -213.65, Epsilon: 0.013
# Episode 871/1000, Total Reward: -68.90, Epsilon: 0.013
# Episode 872/1000, Total Reward: -327.54, Epsilon: 0.013
# Episode 873/1000, Total Reward: -103.86, Epsilon: 0.013
# Episode 874/1000, Total Reward: -161.06, Epsilon: 0.013
# Episode 875/1000, Total Reward: -314.32, Epsilon: 0.012
# Episode 876/1000, Total Reward: -282.03, Epsilon: 0.012
# Episode 877/1000, Total Reward: -153.51, Epsilon: 0.012
# Episode 878/1000, Total Reward: -325.33, Epsilon: 0.012
# Episode 879/1000, Total Reward: -149.52, Epsilon: 0.012
# Episode 880/1000, Total Reward: -99.25, Epsilon: 0.012
# Episode 881/1000, Total Reward: -88.47, Epsilon: 0.012
# Episode 882/1000, Total Reward: -98.50, Epsilon: 0.012
# Episode 883/1000, Total Reward: -56.67, Epsilon: 0.012
# Episode 884/1000, Total Reward: -204.19, Epsilon: 0.012
# Episode 885/1000, Total Reward: -257.21, Epsilon: 0.012
# Episode 886/1000, Total Reward: -291.84, Epsilon: 0.012
# Episode 887/1000, Total Reward: -52.32, Epsilon: 0.012
# Episode 888/1000, Total Reward: -293.69, Epsilon: 0.012
# Episode 889/1000, Total Reward: -193.66, Epsilon: 0.012
# Episode 890/1000, Total Reward: -231.97, Epsilon: 0.012
# Episode 891/1000, Total Reward: -53.71, Epsilon: 0.011
# Episode 892/1000, Total Reward: -269.47, Epsilon: 0.011
# Episode 893/1000, Total Reward: -125.80, Epsilon: 0.011
# Episode 894/1000, Total Reward: -69.41, Epsilon: 0.011
# Episode 895/1000, Total Reward: -207.38, Epsilon: 0.011
# Episode 896/1000, Total Reward: -95.59, Epsilon: 0.011
# Episode 897/1000, Total Reward: -226.19, Epsilon: 0.011
# Episode 898/1000, Total Reward: -112.80, Epsilon: 0.011
# Episode 899/1000, Total Reward: -36.80, Epsilon: 0.011
# Episode 900/1000, Total Reward: -196.85, Epsilon: 0.011
# Episode 901/1000, Total Reward: -116.81, Epsilon: 0.011
# Episode 902/1000, Total Reward: -225.31, Epsilon: 0.011
# Episode 903/1000, Total Reward: -53.16, Epsilon: 0.011
# Episode 904/1000, Total Reward: -102.08, Epsilon: 0.011
# Episode 905/1000, Total Reward: -160.48, Epsilon: 0.011
# Episode 906/1000, Total Reward: -117.10, Epsilon: 0.011
# Episode 907/1000, Total Reward: -320.23, Epsilon: 0.011
# Episode 908/1000, Total Reward: -102.00, Epsilon: 0.011
# Episode 909/1000, Total Reward: -51.40, Epsilon: 0.010
# Episode 910/1000, Total Reward: -185.74, Epsilon: 0.010
# Episode 911/1000, Total Reward: -287.83, Epsilon: 0.010
# Episode 912/1000, Total Reward: -244.72, Epsilon: 0.010
# Episode 913/1000, Total Reward: -96.38, Epsilon: 0.010
# Episode 914/1000, Total Reward: -51.67, Epsilon: 0.010
# Episode 915/1000, Total Reward: -154.36, Epsilon: 0.010
# Episode 916/1000, Total Reward: -200.44, Epsilon: 0.010
# Episode 917/1000, Total Reward: -54.93, Epsilon: 0.010
# Episode 918/1000, Total Reward: -450.98, Epsilon: 0.010
# Episode 919/1000, Total Reward: -287.97, Epsilon: 0.010
# Episode 920/1000, Total Reward: -277.78, Epsilon: 0.010
# Episode 921/1000, Total Reward: -115.26, Epsilon: 0.010
# Episode 922/1000, Total Reward: -51.74, Epsilon: 0.010
# Episode 923/1000, Total Reward: -336.32, Epsilon: 0.010
# Episode 924/1000, Total Reward: -233.35, Epsilon: 0.010
# Episode 925/1000, Total Reward: -341.49, Epsilon: 0.010
# Episode 926/1000, Total Reward: -172.98, Epsilon: 0.010
# Episode 927/1000, Total Reward: -95.97, Epsilon: 0.010
# Episode 928/1000, Total Reward: -224.80, Epsilon: 0.010
# Episode 929/1000, Total Reward: -39.21, Epsilon: 0.010
# Episode 930/1000, Total Reward: -187.44, Epsilon: 0.010
# Episode 931/1000, Total Reward: -220.81, Epsilon: 0.010
# Episode 932/1000, Total Reward: -283.67, Epsilon: 0.010
# Episode 933/1000, Total Reward: -124.40, Epsilon: 0.010
# Episode 934/1000, Total Reward: -119.12, Epsilon: 0.010
# Episode 935/1000, Total Reward: -124.10, Epsilon: 0.010
# Episode 936/1000, Total Reward: -89.76, Epsilon: 0.010
# Episode 937/1000, Total Reward: -244.52, Epsilon: 0.010
# Episode 938/1000, Total Reward: -152.96, Epsilon: 0.010
# Episode 939/1000, Total Reward: -289.47, Epsilon: 0.010
# Episode 940/1000, Total Reward: -147.08, Epsilon: 0.010
# Episode 941/1000, Total Reward: -220.16, Epsilon: 0.010
# Episode 942/1000, Total Reward: -68.18, Epsilon: 0.010
# Episode 943/1000, Total Reward: -222.70, Epsilon: 0.010
# Episode 944/1000, Total Reward: -140.38, Epsilon: 0.010
# Episode 945/1000, Total Reward: 67.55, Epsilon: 0.010
# Episode 946/1000, Total Reward: -91.50, Epsilon: 0.010
# Episode 947/1000, Total Reward: -77.71, Epsilon: 0.010
# Episode 948/1000, Total Reward: -295.03, Epsilon: 0.010
# Episode 949/1000, Total Reward: -67.47, Epsilon: 0.010
# Episode 950/1000, Total Reward: -219.10, Epsilon: 0.010
# Episode 951/1000, Total Reward: -228.73, Epsilon: 0.010
# Episode 952/1000, Total Reward: -104.84, Epsilon: 0.010
# Episode 953/1000, Total Reward: -209.69, Epsilon: 0.010
# Episode 954/1000, Total Reward: -270.26, Epsilon: 0.010
# Episode 955/1000, Total Reward: -101.98, Epsilon: 0.010
# Episode 956/1000, Total Reward: -203.09, Epsilon: 0.010
# Episode 957/1000, Total Reward: -79.87, Epsilon: 0.010
# Episode 958/1000, Total Reward: -290.13, Epsilon: 0.010
# Episode 959/1000, Total Reward: -87.20, Epsilon: 0.010
# Episode 960/1000, Total Reward: -206.90, Epsilon: 0.010
# Episode 961/1000, Total Reward: -116.13, Epsilon: 0.010
# Episode 962/1000, Total Reward: -223.25, Epsilon: 0.010
# Episode 963/1000, Total Reward: -51.99, Epsilon: 0.010
# Episode 964/1000, Total Reward: -10.27, Epsilon: 0.010
# Episode 965/1000, Total Reward: -98.22, Epsilon: 0.010
# Episode 966/1000, Total Reward: -179.37, Epsilon: 0.010
# Episode 967/1000, Total Reward: -48.30, Epsilon: 0.010
# Episode 968/1000, Total Reward: -142.21, Epsilon: 0.010
# Episode 969/1000, Total Reward: -137.27, Epsilon: 0.010
# Episode 970/1000, Total Reward: 25.21, Epsilon: 0.010
# Episode 971/1000, Total Reward: -91.76, Epsilon: 0.010
# Episode 972/1000, Total Reward: -70.16, Epsilon: 0.010
# Episode 973/1000, Total Reward: -91.04, Epsilon: 0.010
# Episode 974/1000, Total Reward: -201.63, Epsilon: 0.010
# Episode 975/1000, Total Reward: -323.49, Epsilon: 0.010
# Episode 976/1000, Total Reward: 20.95, Epsilon: 0.010
# Episode 977/1000, Total Reward: -86.33, Epsilon: 0.010
# Episode 978/1000, Total Reward: -219.52, Epsilon: 0.010
# Episode 979/1000, Total Reward: -84.09, Epsilon: 0.010
# Episode 980/1000, Total Reward: -71.42, Epsilon: 0.010
# Episode 981/1000, Total Reward: -303.07, Epsilon: 0.010
# Episode 982/1000, Total Reward: -111.72, Epsilon: 0.010
# Episode 983/1000, Total Reward: -114.16, Epsilon: 0.010
# Episode 984/1000, Total Reward: -108.91, Epsilon: 0.010
# Episode 985/1000, Total Reward: -186.20, Epsilon: 0.010
# Episode 986/1000, Total Reward: -318.19, Epsilon: 0.010
# Episode 987/1000, Total Reward: -84.67, Epsilon: 0.010
# Episode 988/1000, Total Reward: -189.62, Epsilon: 0.010
# Episode 989/1000, Total Reward: -189.68, Epsilon: 0.010
# Episode 990/1000, Total Reward: -216.65, Epsilon: 0.010
# Episode 991/1000, Total Reward: -201.52, Epsilon: 0.010
# Episode 992/1000, Total Reward: -123.58, Epsilon: 0.010
# Episode 993/1000, Total Reward: -180.56, Epsilon: 0.010
# Episode 994/1000, Total Reward: -197.11, Epsilon: 0.010
# Episode 995/1000, Total Reward: -327.44, Epsilon: 0.010
# Episode 996/1000, Total Reward: -231.19, Epsilon: 0.010
# Episode 997/1000, Total Reward: -66.49, Epsilon: 0.010
# Episode 998/1000, Total Reward: -108.05, Epsilon: 0.010
# Episode 999/1000, Total Reward: -103.38, Epsilon: 0.010
# Episode 1000/1000, Total Reward: -111.84, Epsilon: 0.010

# %%
params = {
    'UPDATE_RATE': 4,
    'BUFFER_SIZE': 100000,
    'BATCH_SIZE': 64,
    'GAMMA': 0.99,
    'EPS_START': 1.0,
    'EPS_END': 0.01,
    'EPS_DECAY': 0.995,
    'TAU': 0.005,
    'LR': 1e-3,
    'HIDDEN_DIMS': [128, 128],
    'EPISODE_NUM': 1000,
    'DEVICE': torch.device("cuda" if torch.cuda.is_available() else "cpu")
}

# Environment setup
env = gym.make("LunarLander-v3")
n_actions = env.action_space.n
state, info = env.reset()
n_observations = len(state)

sum_of_rewards = list()

# Define optimizer and loss function
q_network = QNetwork(n_observations, n_actions, params['HIDDEN_DIMS']).to(device)
optimizer = torch.optim.Adam(q_network.parameters(), lr=params['LR'])
criterion = torch.nn.MSELoss()

# Initialize replay buffer and agent
memory = ReplayBuffer(params['BUFFER_SIZE'], params['BATCH_SIZE'])
agent = DQLearningAgent(
    q_network=q_network,
    memory=memory,
    optimizer= torch.optim.Adam,
    criterion=criterion,
    params=params,
    env=env,
)

# %%
sum_of_rewards = agent.train(num_episodes=params['EPISODE_NUM'])
plot_rewards(sum_of_rewards, show_result=True)
plt.ioff()
plt.show()
# Out:
# Episode 10/1000, Average Reward: -286.21, Epsilon: 0.951
# Episode 20/1000, Average Reward: -124.96, Epsilon: 0.905
# Episode 30/1000, Average Reward: -108.60, Epsilon: 0.860
# Episode 40/1000, Average Reward: -132.84, Epsilon: 0.818
# Episode 50/1000, Average Reward: -147.84, Epsilon: 0.778
# Episode 60/1000, Average Reward: -135.28, Epsilon: 0.740
# Episode 70/1000, Average Reward: -168.47, Epsilon: 0.704
# Episode 80/1000, Average Reward: -178.44, Epsilon: 0.670
# Episode 90/1000, Average Reward: -168.82, Epsilon: 0.637
# Episode 100/1000, Average Reward: -175.06, Epsilon: 0.606
# Episode 110/1000, Average Reward: -209.73, Epsilon: 0.576
# Episode 120/1000, Average Reward: -241.68, Epsilon: 0.548
# Episode 130/1000, Average Reward: -200.29, Epsilon: 0.521
# Episode 140/1000, Average Reward: -176.89, Epsilon: 0.496
# Episode 150/1000, Average Reward: -184.81, Epsilon: 0.471
# Episode 160/1000, Average Reward: -86.10, Epsilon: 0.448
# Episode 170/1000, Average Reward: -160.94, Epsilon: 0.427
# Episode 180/1000, Average Reward: -113.89, Epsilon: 0.406
# Episode 190/1000, Average Reward: -122.53, Epsilon: 0.386
# Episode 200/1000, Average Reward: -144.16, Epsilon: 0.367
# Episode 210/1000, Average Reward: -91.79, Epsilon: 0.349
# Episode 220/1000, Average Reward: -91.45, Epsilon: 0.332
# Episode 230/1000, Average Reward: -106.41, Epsilon: 0.316
# Episode 240/1000, Average Reward: -105.27, Epsilon: 0.300
# Episode 250/1000, Average Reward: -86.59, Epsilon: 0.286
# Episode 260/1000, Average Reward: -79.88, Epsilon: 0.272
# Episode 270/1000, Average Reward: -85.93, Epsilon: 0.258
# Episode 280/1000, Average Reward: -83.64, Epsilon: 0.246
# Episode 290/1000, Average Reward: -35.31, Epsilon: 0.234
# Episode 300/1000, Average Reward: -19.45, Epsilon: 0.222
# Episode 310/1000, Average Reward: -24.59, Epsilon: 0.211
# Episode 320/1000, Average Reward: -41.49, Epsilon: 0.201
# Episode 330/1000, Average Reward: 8.85, Epsilon: 0.191
# Episode 340/1000, Average Reward: 25.53, Epsilon: 0.182
# Episode 350/1000, Average Reward: 25.04, Epsilon: 0.173
# Episode 360/1000, Average Reward: 46.58, Epsilon: 0.165
# Episode 370/1000, Average Reward: 46.46, Epsilon: 0.157
# Episode 380/1000, Average Reward: 135.79, Epsilon: 0.149
# Episode 390/1000, Average Reward: 106.01, Epsilon: 0.142
# Episode 400/1000, Average Reward: 105.06, Epsilon: 0.135
# Episode 410/1000, Average Reward: 67.26, Epsilon: 0.128
# Episode 420/1000, Average Reward: 98.97, Epsilon: 0.122
# Episode 430/1000, Average Reward: 153.77, Epsilon: 0.116
# Episode 440/1000, Average Reward: 103.92, Epsilon: 0.110
# Episode 450/1000, Average Reward: 121.68, Epsilon: 0.105
# Episode 460/1000, Average Reward: 47.85, Epsilon: 0.100
# Episode 470/1000, Average Reward: 119.01, Epsilon: 0.095
# Episode 480/1000, Average Reward: 225.71, Epsilon: 0.090
# Episode 490/1000, Average Reward: 120.08, Epsilon: 0.086
# Episode 500/1000, Average Reward: 238.89, Epsilon: 0.082
# Episode 510/1000, Average Reward: 165.59, Epsilon: 0.078
# Episode 520/1000, Average Reward: 153.72, Epsilon: 0.074
# Episode 530/1000, Average Reward: 250.90, Epsilon: 0.070
# Episode 540/1000, Average Reward: 113.81, Epsilon: 0.067
# Episode 550/1000, Average Reward: -17.11, Epsilon: 0.063
# Episode 560/1000, Average Reward: 203.72, Epsilon: 0.060
# Episode 570/1000, Average Reward: 143.85, Epsilon: 0.057
# Episode 580/1000, Average Reward: 149.66, Epsilon: 0.055
# Episode 590/1000, Average Reward: 200.84, Epsilon: 0.052
# Episode 600/1000, Average Reward: 222.52, Epsilon: 0.049
# Episode 610/1000, Average Reward: 254.93, Epsilon: 0.047
# Episode 620/1000, Average Reward: 223.96, Epsilon: 0.045
# Episode 630/1000, Average Reward: 165.54, Epsilon: 0.043
# Episode 640/1000, Average Reward: 238.55, Epsilon: 0.040
# Episode 650/1000, Average Reward: 99.84, Epsilon: 0.038
# Episode 660/1000, Average Reward: 198.03, Epsilon: 0.037
# Episode 670/1000, Average Reward: 193.29, Epsilon: 0.035
# Episode 680/1000, Average Reward: 192.83, Epsilon: 0.033
# Episode 690/1000, Average Reward: 253.12, Epsilon: 0.031
# Episode 700/1000, Average Reward: 226.50, Epsilon: 0.030
# Episode 710/1000, Average Reward: 264.80, Epsilon: 0.028
# Episode 720/1000, Average Reward: 262.74, Epsilon: 0.027
# Episode 730/1000, Average Reward: 241.10, Epsilon: 0.026
# Episode 740/1000, Average Reward: 261.13, Epsilon: 0.024
# Episode 750/1000, Average Reward: 189.35, Epsilon: 0.023
# Episode 760/1000, Average Reward: 242.20, Epsilon: 0.022
# Episode 770/1000, Average Reward: 258.06, Epsilon: 0.021
# Episode 780/1000, Average Reward: 259.35, Epsilon: 0.020
# Episode 790/1000, Average Reward: 213.71, Epsilon: 0.019
# Episode 800/1000, Average Reward: 260.93, Epsilon: 0.018
# Episode 810/1000, Average Reward: 256.80, Epsilon: 0.017
# Episode 820/1000, Average Reward: 262.58, Epsilon: 0.016
# Episode 830/1000, Average Reward: 267.19, Epsilon: 0.016
# Episode 840/1000, Average Reward: 259.15, Epsilon: 0.015
# Episode 850/1000, Average Reward: 263.58, Epsilon: 0.014
# Episode 860/1000, Average Reward: 242.11, Epsilon: 0.013
# Episode 870/1000, Average Reward: 266.06, Epsilon: 0.013
# Episode 880/1000, Average Reward: 237.93, Epsilon: 0.012
# Episode 890/1000, Average Reward: 281.68, Epsilon: 0.012
# Episode 900/1000, Average Reward: 248.98, Epsilon: 0.011
# Episode 910/1000, Average Reward: 262.30, Epsilon: 0.010
# Episode 920/1000, Average Reward: 270.72, Epsilon: 0.010
# Episode 930/1000, Average Reward: 238.07, Epsilon: 0.010
# Episode 940/1000, Average Reward: 183.12, Epsilon: 0.010
# Episode 950/1000, Average Reward: 258.36, Epsilon: 0.010
# Episode 960/1000, Average Reward: 267.24, Epsilon: 0.010
# Episode 970/1000, Average Reward: 267.34, Epsilon: 0.010
# Episode 980/1000, Average Reward: 244.22, Epsilon: 0.010
# Episode 990/1000, Average Reward: 254.57, Epsilon: 0.010
# Episode 1000/1000, Average Reward: 269.38, Epsilon: 0.010

# %% [markdown]
# # Evaluation
#
# In order to evaluate the model, we use the following function to measure the average reward and it's standard deviation.

# %%
def evaluate_policy(env, agent, num_episodes=10):
    """
    Evaluates the performance of a policy over a number of episodes.
    Args:
        env: The environment to evaluate the policy in.
        agent: The agent to evaluate.
        num_episodes: Number of episodes to evaluate.
    Returns:
        mean_reward: Average reward over all episodes.
        std_reward: Standard deviation of rewards.
    """
    rewards = []

    for episode in range(num_episodes):
        state, _ = env.reset()
        total_reward = 0
        done = False

        while not done:
            # Select the greedy action (no exploration during evaluation)
            action = agent.act(state, greedy=True)

            # Step the environment
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated

            # Accumulate reward for this episode
            total_reward += reward
            state = next_state

        # Store total reward for this episode
        rewards.append(total_reward)

    # Calculate mean and standard deviation of rewards
    mean_reward = np.mean(rewards)
    std_reward = np.std(rewards)

    return mean_reward, std_reward

# %% [markdown]
# The code below will be used for simple Q-Learning evaluation.

# %%
def evaluate_policy_q(env, agent, num_episodes=10):
    total_rewards = []
    for _ in range(num_episodes):
        state = agent.discretize_state(env.reset()[0])
        total_reward = 0
        done = False

        while not done:
            action = agent.act(state, greedy=True)
            next_state_raw, reward, done, _, _ = env.step(action)
            state = agent.discretize_state(next_state_raw)
            total_reward += reward
        total_rewards.append(total_reward)

    mean_reward = np.mean(total_rewards)
    std_reward = np.std(total_rewards)
    return mean_reward, std_reward

# %%
#Q-Learning reward
mean_reward, std_reward = evaluate_policy_q(env, q_agent)
print(f"mean_reward = {mean_reward:.2f} +/- {std_reward:.4f}")
# Out:
# mean_reward = -135.85 +/- 60.5222

# %%
#DQN reward
mean_reward, std_reward = evaluate_policy(env, agent)
print(f"mean_reward = {mean_reward:.2f} +/- {std_reward:.4f}")
# Out:
# mean_reward = 266.52 +/- 8.8190

# %%
env = gym.make("LunarLander-v3", render_mode='rgb_array')  # Ensure render_mode is set
video = create_policy_eval_video(env, agent, 'greedy_policy', num_episodes=3)
video  # Display video in Jupyter Notebook
# Out:
#         <video width="640" height="480" controls>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %% [markdown]
# **Question :** Which of these algorithms have better results? What causes the gap in these results?

# %% [markdown]
# **Answer :**
# In the comparison between **Q-Learning** and **Deep Q-Learning (DQN)**, the performance of **DQN** is significantly better in environments with large or continuous state spaces, such as **LunarLander**. This advantage comes from DQN's ability to use a neural network to approximate the Q-function and generalize to unseen states, whereas Q-Learning relies on discretizing the state space, which reduces accuracy and efficiency. Additionally, techniques like **Experience Replay** and **Target Networks** in DQN contribute to more stable and efficient learning. In this specific case, **DQN** has outperformed Q-Learning by effectively managing the continuous state space and leveraging these advanced techniques.
